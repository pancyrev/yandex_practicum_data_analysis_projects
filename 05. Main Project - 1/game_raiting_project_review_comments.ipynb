# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Привет, Ринат! Спасибо за проверку, ценные комментарии и полезные ссылки.
#
# Устранил в проекте следующие замечания:
# * добавил содержание;
# * оставил пропуски в столбцах user_score и criic_score;
# * заполнил пропуски в rating рейтингом RP;
# * добавил проверку дубликатов;
# * исправил подписи на графиках;
# * выброс удалил для платформы DS;
# * добавил платформу 3DS в актуальный список;
# * добавил диаграмму ~~разброса~~ размаха со 100% масштабом;
# * исправил выводы по корреляции между рейтингами и продажами;
# * добавил диаграммы размаха и исправил выбор платформ в анализе общего распределения игр по жанрам;
# * добавил категорию "другие" в анализе популярных платформ и жанров;
# * откорректировал выводы при проверке гипотез;
# * откорректировал финальный вывод.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="4", color = "black">
# <br />  Привет, Евгений :) Спасибо за все исправления и подсказки. На проекте порядок
#
# <b>Навыки первого модуля освоены замечательно:</b>
#
#  + выдвижении гипотез о пропусках в данных, заполнении или удалении,
#  + подготовке данных для решения главной задачи проекта
#  + исследовании неочищенных данных,
#  + подборе и создании графиков,
#  + программировании,
#  + автоматизации однотипных действий;
#  + выстраивании структуры проекта и обеспечении аккуратности кода;
#  + анализе данных,
#  + определении прибыльности и устойчивости продаж по выбранному параметру (жанр, платформа),
#  + составлении портрета пользователя,
#  + формулировании и проверке двухсторонних гипотез, интерпретации значения p-value - требует повторения недели через две </b>(для профилактики :) )
#  + формировании рекомендаций для бизнеса
#
# <b>Поздравляю с успешно сданным сборным проектом и завершением первого модуля <br />на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Евгений :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться).
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Посмотрите,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?" data-toc-modified-id="Посмотрите,-сколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?</a></span></li><li><span><a href="#Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам." data-toc-modified-id="Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам.</a></span></li><li><span><a href="#Определить-актуальный-период-для-прогноза" data-toc-modified-id="Определить-актуальный-период-для-прогноза-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Определить актуальный период для прогноза</a></span></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ." data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.</a></span></li><li><span><a href="#Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат." data-toc-modified-id="Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.</a></span></li><li><span><a href="#Посмотрите,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Соотнесите-выводы-с-продажами-игр-на-других-платформах." data-toc-modified-id="Посмотрите,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Соотнесите-выводы-с-продажами-игр-на-других-платформах.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Соотнесите выводы с продажами игр на других платформах.</a></span></li><li><span><a href="#Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?" data-toc-modified-id="Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Составьте-портрет-пользователя-каждого-региона" data-toc-modified-id="Составьте-портрет-пользователя-каждого-региона-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Составьте портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Самые-популярные-платформы-для-каждого-региона-(топ-5).-Опишите-различия-в-долях-продаж." data-toc-modified-id="Самые-популярные-платформы-для-каждого-региона-(топ-5).-Опишите-различия-в-долях-продаж.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Самые популярные платформы для каждого региона (топ-5). Опишите различия в долях продаж.</a></span></li><li><span><a href="#Самые-популярные-жанры-(топ-5).-Поясните-разницу." data-toc-modified-id="Самые-популярные-жанры-(топ-5).-Поясните-разницу.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Самые популярные жанры (топ-5). Поясните разницу.</a></span></li><li><span><a href="#Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?" data-toc-modified-id="Влияет-ли-рейтинг-ESRB-на-продажи-в-отдельном-регионе?-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Влияет ли рейтинг ESRB на продажи в отдельном регионе?</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые</a></span></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные" data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action и Sports разные</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Добавил содержание
#
# </div>

# %% [markdown]
# # Исследование параметров популярности компьютерных игр <a class="tocSkip">

# %% [markdown]
# # Общая информация

# %% [markdown]
# **Входные данные**: данные по играм до 2016 года с информацией по продажам и оценкой критиков и пользователей.
#
# **Цель**: выявить определяющие успешность игры закономерности.
#
# **Задачи**:
#
# Шаг 1. Откройте файл с данными и изучите общую информацию
# Путь к файлу: /datasets/games.csv.
# Шаг 2. Подготовьте данные
#
#     Замените названия столбцов (приведите к нижнему регистру);
#     Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
#     Обработайте пропуски при необходимости:
#         Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
#         Опишите причины, которые могли привести к пропускам;
#         Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
#     Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# Шаг 3. Проведите исследовательский анализ данных
#
#     Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#     Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
#     Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.
#     Не учитывайте в работе данные за предыдущие годы.
#     Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
#     Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
#     Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
#     Соотнесите выводы с продажами игр на других платформах.
#     Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# Шаг 4. Составьте портрет пользователя каждого региона
# Определите для пользователя каждого региона (NA, EU, JP):
#
#     Самые популярные платформы (топ-5). Опишите различия в долях продаж.
#     Самые популярные жанры (топ-5). Поясните разницу.
#     Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# Шаг 5. Проверьте гипотезы
#
#     Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#     Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
#
#     Как вы сформулировали нулевую и альтернативную гипотезы;
#     Какой критерий применили для проверки гипотез и почему.
#
# Шаг 6. Напишите общий вывод

# %% [markdown]
# # Обзор данных

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
import seaborn as sns

# %%
# чтение данных
df = pd.read_csv('/datasets/games.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
# количество пропусков
df.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# NA_sales              0
# EU_sales              0
# JP_sales              0
# Other_sales           0
# Critic_Score       8578
# User_Score         6701
# Rating             6766
# dtype: int64

# %%
# количество пропусков в процентах
df.isna().sum() / len(df) * 100
# Out:
# Name                0.011965
# Platform            0.000000
# Year_of_Release     1.609333
# Genre               0.011965
# NA_sales            0.000000
# EU_sales            0.000000
# JP_sales            0.000000
# Other_sales         0.000000
# Critic_Score       51.319174
# User_Score         40.089740
# Rating             40.478612
# dtype: float64

# %% [markdown]
# **Выводы**
#
# Всего записей 16715 строк.
# Столбцы `Name`, `Year_of_Release`, `Genre`, `Critic_Score`, `User_Score`, `Rating` имеют пропуски.
# Необходимо изменить тип данных в столбцах `Year_of_Release` и `Critic_Score` на тип `int`, столбец `User_Score` на тип `float`.
# Необходимо изменить названия столбцов в соответствие со стилистическими нормами.

# %%
# check
# пропущенные значения бары

# check
def pass_value_barh(df):
    (
        (df.isna().mean()*100)
        .to_frame()
        .rename(columns = {0:'space'})
        .query('space > 0')
        .sort_values(by = 'space', ascending = True)
        .plot(kind= 'barh', figsize=(17,5), rot = -5, legend = False, fontsize = 16)
        .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
    );

# %%
pass_value_barh(df)

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# Замените названия столбцов (приведите к нижнему регистру);
# Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# Обработайте пропуски при необходимости:
# * Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# * Опишите причины, которые могли привести к пропускам;
# * Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей. Отдельно разберите это значение и опишите, как его обработать;
#
# Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
# приведем названия столбцов к нижнему регистру
df.columns = df.columns.str.lower()

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />стоит привести к нижнему регистру и содержимое категориальных столбцов, в т.ч. с целью поиска дубликатов

# %%
# проверим столбец user_score на уникальные значения:
df['user_score'].unique()
# Out:
# array(['8', nan, '8.3', '8.5', '6.6', '8.4', '8.6', '7.7', '6.3', '7.4',
#        '8.2', '9', '7.9', '8.1', '8.7', '7.1', '3.4', '5.3', '4.8', '3.2',
#        '8.9', '6.4', '7.8', '7.5', '2.6', '7.2', '9.2', '7', '7.3', '4.3',
#        '7.6', '5.7', '5', '9.1', '6.5', 'tbd', '8.8', '6.9', '9.4', '6.8',
#        '6.1', '6.7', '5.4', '4', '4.9', '4.5', '9.3', '6.2', '4.2', '6',
#        '3.7', '4.1', '5.8', '5.6', '5.5', '4.4', '4.6', '5.9', '3.9',
#        '3.1', '2.9', '5.2', '3.3', '4.7', '5.1', '3.5', '2.5', '1.9', '3',
#        '2.7', '2.2', '2', '9.5', '2.1', '3.6', '2.8', '1.8', '3.8', '0',
#        '1.6', '9.6', '2.4', '1.7', '1.1', '0.3', '1.5', '0.7', '1.2',
#        '2.3', '0.5', '1.3', '0.2', '0.6', '1.4', '0.9', '1', '9.7'],
#       dtype=object)

# %%
# заменим "tbd" на "nan"
df['user_score'] = df['user_score'].replace('tbd', np.nan)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Верно, по своей сути tbd и является Nan. Отлично, что определяешь неявные пропущенные значения.

# %% [markdown]
# **1. Столбец `name`**

# %%
# Исследуем пропуски
df[df['name'].isna()]
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# Всего две строки без имени игры. Для них отсутствуют данные по жанру и рейтингу. Можно удалить эти строки, т.к. они не повлияют на общую статистику

# %%
df = df.dropna(subset=['name']).reset_index(drop=True)

# %% [markdown]
# **2. Столбец `platform`**

# %%
df['platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# Дубликатов и пропусков не обнаружено.

# %% [markdown]
# **3. Столбец `year_of_release`**

# %% [markdown]
# Заметим, что некоторые названия игр имеют год. Присвоим этот год году выпуска игры.

# %%
df['year_of_release'].isna().sum()
# Out:
# 269

# %%
def name_year_parcer(row):
    if pd.isna(row['year_of_release']):
        for i in row['name'].split():
            if i.isdigit() and int(i) >= 1980:
                return int(i)
    else:
        return row['year_of_release']
        
df['year_of_release'] = df.apply(name_year_parcer, axis=1)

# %%
print(
    df['year_of_release'].isna().sum(),
    df['year_of_release'].isna().sum() / len(df) * 100
)
# Out:
# 254 1.5197750254293065

# %% [markdown]
# Восстановить остальные даты выпуска игр по имеющимся данным невозможно. Пропущенных данных 254 строки. Это 1,5% от всей информации, поэтому удалим пропущенные значения.

# %%
df = df.dropna(subset=['year_of_release']).reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> отличное решение
#
#         df = df.dropna(subset=['year_of_release']).reset_index(drop=True)

# %% [markdown]
# **4. Столбец `genre`**

# %%
df['genre'].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %% [markdown]
# Дубликатов и пропусков не обнаружено.

# %% [markdown]
# **5. Столбец `na_sales`**

# %%
df['na_sales'].describe()
# Out:
# count    16459.000000
# mean         0.264293
# std          0.818686
# min          0.000000
# 25%          0.000000
# 50%          0.080000
# 75%          0.240000
# max         41.360000
# Name: na_sales, dtype: float64

# %%
q_01 = np.quantile(df['na_sales'], 0.01)
q_99 = np.quantile(df['na_sales'], 0.99)
df['na_sales'].hist(bins=30, range=(q_01,q_99))
plt.xlabel('sales, mln')
plt.ylabel('number of sales')
plt.title('NA sales histogramm');

# %% [markdown]
# Пропусков не обнаружено. Значения распределны от 0 до 41,36 млн. Среднее значение равно 0,26 млн. Медианное значение равно 0,08 млн. Аномальных значений не обнаружено.

# %% [markdown]
# **6. Столбец `eu_sales`**

# %%
df['eu_sales'].describe()
# Out:
# count    16459.000000
# mean         0.146075
# std          0.506840
# min          0.000000
# 25%          0.000000
# 50%          0.020000
# 75%          0.110000
# max         28.960000
# Name: eu_sales, dtype: float64

# %%
q_01 = np.quantile(df['eu_sales'], 0.01)
q_99 = np.quantile(df['eu_sales'], 0.99)
df['eu_sales'].hist(bins=30, range=(q_01,q_99))
plt.xlabel('sales, mln')
plt.ylabel('number of sales')
plt.title('EU sales histogramm');

# %% [markdown]
# Пропусков не обнаружено. Значения распределны от 0 до 28,96 млн. Среднее значение равно 0,15 млн. Медианное значение равно 0,02 млн. Аномальных значений не обнаружено.

# %% [markdown]
# **7. Столбец `jp_sales`**

# %%
df['jp_sales'].describe()
# Out:
# count    16459.000000
# mean         0.078421
# std          0.310966
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.040000
# max         10.220000
# Name: jp_sales, dtype: float64

# %%
q_01 = np.quantile(df['jp_sales'], 0.01)
q_99 = np.quantile(df['jp_sales'], 0.99)
df['jp_sales'].hist(bins=30, range=(q_01,q_99))
plt.xlabel('sales, mln')
plt.ylabel('number of sales')
plt.title('JP sales histogramm');

# %% [markdown]
# Пропусков не обнаружено. Значения распределны от 0 до 10,22 млн. Среднее значение равно 0,08 млн. Медианное значение равно 0,0 млн. Наблюдается много игр, неимеющих продаж в Японии. Возможно это связано с региональными особенностями.

# %% [markdown]
# **8. Столбец `other_sales`**

# %%
df['other_sales'].describe()
# Out:
# count    16459.000000
# mean         0.047669
# std          0.188051
# min          0.000000
# 25%          0.000000
# 50%          0.010000
# 75%          0.030000
# max         10.570000
# Name: other_sales, dtype: float64

# %%
q_01 = np.quantile(df['other_sales'], 0.01)
q_99 = np.quantile(df['other_sales'], 0.99)
df['other_sales'].hist(bins=30, range=(q_01,q_99))
plt.xlabel('sales, mln')
plt.ylabel('number of sales')
plt.title('Other world sales histogramm');

# %% [markdown]
# Пропусков не обнаружено. Значения распределны от 0 до 10,57 млн. Среднее значение равно 0,05 млн. Медианное значение равно 0,01 млн. Аномальных значений не обнаружено.

# %%
# суммарные продажи во всех регионах
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# можно
#
#     df['total_sales'] = df[['na_sales','eu_sales','jp_sales', 'other_sales']].sum(axis = 1)

# %% [markdown]
# **9. Столбец `critic_score`**

# %% [markdown]
# Столбец `critic_score` содержит 51% пропусков.
# Проверим корреляцию суммарных продаж и отзывов критиков.

# %%
df.plot(x='total_sales', y='critic_score', kind='scatter');
plt.title('Total sales with critic score diagramm');

# %%
df['total_sales'].corr(df['critic_score'])
# Out:
# 0.245853277312419

# %% [markdown]
# Явной корреляции не наблюдается.
# По имеющейся информации заполнить пропуски невозможно, поэтому оставим пропуски как есть.

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ты проделал работу по восстановлению пропусков. Но такую значительную долю пропусков вряд ли можно корректно восстановить по имеющимся значениям.
#
# Стоит вернуть пропуски

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Оставил пропуски как есть
#
# </div>

# %% [markdown]
# **10. Столбец `user_score`**

# %% [markdown]
# Столбец `user_score` содержит 40% пропусков.
# Проверим корреляцию суммарных продаж и отзывов пользователей.

# %%
# Заменим тип переменной на float, чтобы построить график
df['user_score'] = df['user_score'].astype('float')

# %%
df.plot(x='total_sales', y='user_score', kind='scatter');
plt.title('Total sales with user score diagramm');

# %%
df['total_sales'].corr(df['user_score'])
# Out:
# 0.08797644835493139

# %% [markdown]
# Явной корреляции не наблюдается.
# По имеющейся информации заполнить пропуски невозможно, поэтому оставим пропуски как есть.

# %% [markdown]
# <div class="alert alert-dnger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Ты проделал работу по восстановлению пропусков. Но такую значительную долю пропусков вряд ли можно корректно восстановить по имеющимся значениям.
#
# Стоит вернуть пропуски

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Оставил пропуски как есть
#
# </div>

# %% [markdown]
# **11. Столбец `rating`**

# %% [markdown]
# Столбец `rating` имеет 40% пропусков.
# Заменим все пропуски на рейтинг «RP» («Rating Pending»):  продукт был отправлен в ESRB и ожидает присвоения рейтинга.

# %%
df.loc[df['rating'].isna(), 'rating'] = 'RP'

# %% [markdown]
# Исследуем рейтинги

# %%
df['rating'].value_counts()
# Out:
# RP      6682
# E       3930
# T       2905
# M       1536
# E10+    1394
# EC         8
# K-A        3
# AO         1
# Name: rating, dtype: int64

# %%
# посчитаем процент каждой категории рейтинга:
df['rating'].value_counts()/len(df) * 100
# Out:
# RP      40.597849
# E       23.877514
# T       17.649918
# M        9.332280
# E10+     8.469530
# EC       0.048606
# K-A      0.018227
# AO       0.006076
# Name: rating, dtype: float64

# %% [markdown]
# Рейтинг RP - "ожидает присовение" составляет 40,6% данных.
# Рейтинг E - "для всех" - 23,9% данных.
# Рейтинг Т - "подросткам" - 17,6% данных.
# Рейтинг М - "для взрослых" - 9,3% данных.
# Рейтинг Е10+ - "для всех от 10 лет и старше" - 8,5%.
# Рейтинги ЕС "для детей младшего возраста", К-А "для детей младшего возраста" и АО "только для взрослых" составляют менее одного процента данных.

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит заменить все пропуски на RP, так мы сможем увидеть отличия рынков
#
#         (df['year_of_release']==2016)
#
# Стоит поработать со столбцом рейтингов, посмотреть на частотность использования всех категорий рейтинга
#
#             EC         8
#             K-A        3
#             RP         1
#             AO         1

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Заполнил пропуски рейтингом RP.
# Поработал со столбцом рейтингов и посмотрел на частотность использования категорий рейтинга.
#
# </div>

# %% [markdown]
# **12. Замена типа данных**

# %%
# заменим тип данных в столбце user_score на float
df['user_score'] = df['user_score'].astype('float')

# заменим тип данных в столбцах year_of_release и critic_score на int
df['year_of_release'] = df['year_of_release'].astype('int')
df['critic_score'] = df['critic_score'].astype('Int64')

# %% [markdown]
# **13. Проверка дубликатов**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов не обнаружено

# %% [markdown]
# **Выводы:**
# в данном разделе был проведен анализ данных на наличие ошибок и пропусков и преобразование данных к нужному типу.
# Названия столбцов приведены к нижнему регистру.
# Удалены строки с играми без названия.
# В столбцы с годом выпуска были добавлены годы выпуска игр из их названий. Строки без дат выпуска были удалены.
# Столбцы с рейтингами критиков и пользователей были заполнены медианными значениями в соответсвии с жанром игр.
# Столбцы с рейтингом ESRB для игр выпущенных в 2016 году были заполнены рейтингом "RP". Остальные пропуски были оставлены как есть.
# Для столбца с рейтингом пользователя был назначен тип "float".
# Для столбцов с рейтингом критиков и и годом выпуска был назначен тип "int".
# Были посчитаны суммарные продажи во всех регионах. Данные занесены в столбец "total_sales".

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />  Данные изучены и добавлены, что можно добавить:
#
# + поиск дубликатов важный этап исследования данных, даже если нам кажется, что с данными все хорошо

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Добавил проверку дубликатов
#
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16459 entries, 0 to 16458
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16459 non-null  object
#  1   platform         16459 non-null  object
#  2   year_of_release  16459 non-null  int64
#  3   genre            16459 non-null  object
#  4   na_sales         16459 non-null  float64
#  5   eu_sales         16459 non-null  float64
#  6   jp_sales         16459 non-null  float64
#  7   other_sales      16459 non-null  float64
#  8   critic_score     7994 non-null   Int64
#  9   user_score       7472 non-null   float64
#  10  rating           16459 non-null  object
#  11  total_sales      16459 non-null  float64
# dtypes: Int64(1), float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# # Анализ данных

# %% [markdown]
# ## Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
# Построим график выпуска игр по годам
plt.figure(figsize=(12,5))
df.groupby('year_of_release').agg('count').na_sales.plot()
plt.xlabel('Год выпуска')
plt.ylabel('Количество игр')
plt.title('Количество выпущенных игр по годам')
plt.grid(True)

# %% [markdown]
# Пик выпуска игр попадает на период 2007-2009гг, затем выпуск игр снижается. На пике выпускалось более 1400 игр в год. До 1993 года выпускалось мало игр.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Классный график, наглядный
#
# Подписи осей на графиках и название стоит приводить на языке проекта :)

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Исправил подписи на графиках
#
# </div>

# %% [markdown]
# ## Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам.

# %%
# Выведем список платформ по суммарным продажам
df.groupby('platform')['total_sales'].agg('sum').sort_values(ascending=False).head(10)
# Out:
# platform
# PS2     1247.28
# X360     961.30
# PS3      931.34
# Wii      891.18
# DS       802.79
# PS       727.58
# PS4      314.14
# GBA      312.88
# PSP      289.54
# 3DS      257.81
# Name: total_sales, dtype: float64

# %% [markdown]
# Наибольшие продажи у платформ PS2, X360, PS3, Wii, DS и т.д.
# Построим график десяти наиболее продаваемых платформ по годам.

# %%
platforms = list(df.groupby('platform')['total_sales'].agg('sum').sort_values(ascending=False).index)[0:9]
plt.figure(figsize=(12,5))
for i in platforms:
    df[df['platform']==i].groupby(['year_of_release']).total_sales.agg("count").plot()

plt.grid(True)
plt.legend(platforms);
plt.xlabel('Год выпуска')
plt.ylabel('Продажи, млн')
plt.title('Суммарные продажи по платформам');

# %%
# Проверим выброс платформы игры для латформы DS. DS выпускалась с 2004 года
df[(df['platform']=='DS') & (df['year_of_release']<2004)]
# Out:
#                                       name platform  year_of_release   genre  \
# 15717  Strongest Tokyo University Shogi DS       DS             1985  Action
#
#        na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 15717       0.0       0.0      0.02          0.0          <NA>         NaN
#
#       rating  total_sales
# 15717     RP         0.02

# %% [markdown]
# Для игры был случайно назначен тип платформы DS. Игра не обладает выдающимися рейтингами и продажами, поэтому удалим ее из базы.

# %%
df = df.drop(df[(df['platform']=='DS') & (df['year_of_release']<2004)].index).reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Странный выброс 1985 года, у какой-то из платформ, можно посмотреть когда платформу выпустили на рынок
#
# и не важно даже то, что мы с ней не работаем... любые аномалии д.б. зафиксированы

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Выброс удалил
#
# </div>

# %%
plt.figure(figsize=(12,5))
for i in platforms:
    df[df['platform']==i].groupby(['year_of_release']).total_sales.agg("count").plot()

plt.grid(True)
plt.legend(platforms);
plt.xlabel('Год выпуска')
plt.ylabel('Продажи, млн')
plt.title('Суммарные продажи по платформам');

# %% [markdown]
# На графике видно, что для платформ характерна периодичность их существования.
# Определим средний период существования платформ.

# %%
# соберем таблицу с первым и последним годом выпуска игры для платформы
platform_year = (
    df.pivot_table(
        index='platform', 
        values='year_of_release', 
        aggfunc=['min', 'max']
    ).
    sort_values(('max', 'year_of_release'))
)
platform_year.columns = ['min_year', 'max_year']

# уберем из таблицы строки max_year < 2016 - платформы, которые не ушли с рынка на сегодняшний день
platform_year = platform_year[platform_year['max_year']<2016]
platform_year['delta'] = platform_year['max_year'] - platform_year['min_year'] + 1

# %% [markdown]
# Построим гистограмму:

# %%
platform_year['delta'].hist(bins=30, edgecolor='black', alpha=0.7)

# Отбросим аномально большое значение и короткие сроки менее трех
(
    platform_year[
        (platform_year['delta']>3) & 
        (platform_year['delta'] < 25)
    ]
    ['delta'].
    hist(bins=20, edgecolor='black', alpha=0.7)
);
plt.xlabel('Продолжительность лет')
plt.ylabel('Количество платформ')
plt.title('Длительность продаж по платформам')
plt.legend(['Длительность', 'Длительность > 3']);

# %%
# не будем учитывать платформы, просуществовавшие менее трех лет 
platform_year[(platform_year['delta']>3)].describe()
# Out:
#           min_year     max_year      delta
# count    16.000000    16.000000  16.000000
# mean   1994.687500  2002.875000   9.187500
# std       7.096654     7.455423   2.809953
# min    1980.000000  1989.000000   4.000000
# 25%    1990.000000  1998.250000   7.000000
# 50%    1995.000000  2002.500000  10.000000
# 75%    2000.000000  2008.000000  11.250000
# max    2004.000000  2015.000000  14.000000

# %% [markdown]
# Среднее значение равно 9,2. Медианное значение равно 10 лет.
# Примем активное время существования платформы 10 лет.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> отличное определение среднего периода активных продаж у платформ, молодец

# %% [markdown]
# ## Определить актуальный период для прогноза

# %% [markdown]
# Для определения актуального периода необходимо рассматривать платформы, активные на текущее время. Т.е. ищем платформы, имеющие продажи на текущий год.

# %%
df[df['year_of_release']>2015]['platform'].unique()
# Out:
# array(['PS4', '3DS', 'XOne', 'WiiU', 'PS3', 'PC', 'X360', 'PSV', 'Wii'],
#       dtype=object)

# %%
# Построим графики суммарных продаж по годам активных платформ
platforms = list(df[df['year_of_release']>2015]['platform'].unique())
plt.figure(figsize=(12,5))
for i in platforms:
    df[df['platform']==i].groupby(['year_of_release']).total_sales.agg("count").plot()
plt.grid(True)
plt.legend(platforms)
plt.xlim(2005,2016)
plt.xlabel('Год выпуска')
plt.ylabel('Продажи, млн')
plt.title('Суммарные продажи по платформам');

# %%
print('Начало продаж PS4 и XOne:',
      df[(df['platform']=='PS4') | (df['platform']=='XOne')]['year_of_release'].min())
# Out:
# Начало продаж PS4 и XOne: 2013

# %% [markdown]
# На графиках можно выделить три группы платформ:
# 1. Платформы, продажи которых в 2016 году стремятся к нулю: Wii, X360, PS3, 3DS, PSV, WiiU - игровые приставки предыдущего поколения или портативные игровые системы.
# 2. Платформы, продажи которых растут в 2016 году: PS4, XOne.
# 3. PC - персональные компьютеры.
#
# Портативные игровые системы 3DS, PSV, WiiU на сегодняшний день теряют актуальность из-за насыщенного рынка игр для мобильных устройств.
# Актуальным примем период между началом продаж PS4 и XOne: 2013 год до 2016 года. Для данного периода определим жанры игр, которые являются лидерами продаж. Полученная информация позволит спрогнозировать прибыльные жанры в будущем.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> отличное определение перечня актуальных платформ, молодец

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> 3DS неплохо держится, можно ее оставить
#
# за 2016 год данные в базе неполные

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Оставил 3DS
#
# </div>

# %% [markdown]
# ## Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %% [markdown]
# В предыдущем разделе было определено 9 платформ, активных на сегодняшний день: Wii, X360, PS3, 3DS, PSV, WiiU, PS4, XOne и PC.
# Портативные игровые системы PSV, WiiU на сегодняшний день неактуальны.
# Wii, X360 и PS3 - игровые приставки предыдущего поколения, также неактуальны сегодня.
# Таким образом, потенциально прибыльные платформы - новые поколения игровых приставок PS4, XOne, портативная игровая система 3DS и персональные компьютеры PC.

# %% [markdown]
# ## Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %% [markdown]
# Исследуем параметры распределения продаж для выбранных платформ 3DS, X360, PS3, PC, PS4 и XOne.

# %%
# Соберем датафрейм с выбранными платформами и актуальным периодом продаж
sort_platform = df[
    ((df['platform']=='3DS') |
    (df['platform']=='X360') |
    (df['platform']=='PS3') |
    (df['platform']=='PC') |
    (df['platform']=='PS4') |
    (df['platform']=='XOne')) &
    (df['year_of_release']>=2013)
][['platform', 'total_sales']]

# отсортируем платформы по средним продажам
order = sort_platform.groupby('platform')['total_sales'].agg('mean').sort_values(ascending=False).index

# построим ящики с усами для каждой платформы без выбросов
sns.boxplot(
    x=sort_platform['platform'], 
    y=sort_platform['total_sales'], 
    order = order, 
    showfliers=False, 
    showmeans=True, 
    meanline=True
)
plt.grid(True)
plt.xlabel('Платформа')
plt.ylabel('Суммарные продажи');
plt.show()

# построим ящики с усами для каждой платформы с выбросами
sns.boxplot(
    x=sort_platform['platform'], 
    y=sort_platform['total_sales'], 
    order = order, 
    showfliers=True, 
    showmeans=True, 
    meanline=True
)
plt.grid(True)
plt.xlabel('Платформа')
plt.ylabel('Суммарные продажи');

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />наверно очепятка
#
#     (df['platform']=='Wii')
#
# стоит добавить 3DS

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Добавил 3DS
#
# </div>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для более полной оценки продаж на платформах стоит добавить график со 100% масштабом

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Добавил график со 100% масштабом
#
# </div>

# %%
# параметры распределений по  платформам
sort_platform.groupby('platform').describe().sort_values(by=('total_sales', 'mean'),ascending=False)
# Out:
#          total_sales
#                count      mean       std   min   25%    50%    75%    max
# platform
# PS4            392.0  0.801378  1.609456  0.01  0.06  0.200  0.730  14.63
# X360           186.0  0.735484  1.663275  0.01  0.08  0.265  0.795  16.27
# XOne           247.0  0.645020  1.036139  0.01  0.06  0.220  0.685   7.39
# PS3            345.0  0.525884  1.451939  0.01  0.04  0.150  0.510  21.05
# 3DS            303.0  0.472772  1.381347  0.01  0.04  0.090  0.280  14.60
# PC             189.0  0.208624  0.352304  0.01  0.03  0.080  0.230   3.05

# %% [markdown]
# По всем диаграммам видно, что среднее отличается от медианного значения. Значит для каждой платформы есть игры с очень высокими продажами. Медианные значения и разброс для лидеров близки.
# Лидер по средним продажам PS4. Затем X360 и XOne.

# %% [markdown]
# ## Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Соотнесите выводы с продажами игр на других платформах.

# %% [markdown]
# 1. Исследуем продажи/отзывы для платформ PS3, X360.

# %%
# построим диаграмму рассеяния рейтинга критиков
ax=df[(df['platform']=='X360')].plot(x='total_sales', y='critic_score', kind='scatter')
df[(df['platform']=='PS3')].plot(ax=ax, x='total_sales', y='critic_score', kind='scatter', color='orange')
plt.legend(['X360', 'PS3'])
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг критиков')
plt.title('Зависимость рейтинга критиков от продаж PS3 и X360');

# %%
# построим диаграмму рассеяния рейтинга пользователей
ax=df[(df['platform']=='X360')].plot(x='total_sales', y='user_score', kind='scatter')
df[(df['platform']=='PS3')].plot(ax=ax, x='total_sales', y='user_score', kind='scatter', color='orange')
plt.legend(['X360', 'PS3'])
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг пользователей')
plt.title('Зависимость рейтинга пользователей от продаж PS3 и X360');

# %%
# коэффициент корреляции рейтинга польователя и суммарными продажами платформы X360
df[df['platform']=='X360']['total_sales'].corr(df[df['platform']=='X360']['user_score'])
# Out:
# 0.11381349200527156

# %%
# коэффициент корреляции рейтинга критиков и суммарными продажами платформы X360
df[df['platform']=='X360']['total_sales'].corr(df[df['platform']=='X360']['critic_score'].astype(float))
# Out:
# 0.39314972428236244

# %%
df[df['platform']=='X360']['critic_score'].isna().sum()
# Out:
# 339

# %%
# коэффициент корреляции рейтинга польователя и суммарными продажами платформы PS3
df[df['platform']=='PS3']['total_sales'].corr(df[df['platform']=='PS3']['user_score'])
# Out:
# 0.12841562938563025

# %%
# коэффициент корреляции рейтинга критиков и суммарными продажами платформы PS3
df[df['platform']=='PS3']['total_sales'].corr(df[df['platform']=='PS3']['critic_score'].astype(float))
# Out:
# 0.4327589578997136

# %% [markdown]
# По диаграмме рассеяния корреляции между рейтингом пользователей и критиков и суммарными продажам не наблюдается.
# Коэффициенты корреляции невысокие.
# Чтобы проверить зависимость продаж от рейтинга построим график зависимости средних продаж от средних рейтингов критиков и пользователей.

# %%
# построим корзины для продаж X360 и PS3
df['sales_X360_q'] = pd.qcut(df[(df['platform']=='X360')]['total_sales'],5)
df['sales_PS3_q'] = pd.qcut(df[(df['platform']=='PS3')]['total_sales'],5)

# %%
# Построим график продаж и рейтинга критиков
ax = (
    df.groupby('sales_X360_q')[['total_sales', 'critic_score']].
    agg(['mean']).
    plot(
        x=('total_sales','mean'), 
        y=('critic_score','mean')
    )
)
(
    df.groupby('sales_PS3_q')[['total_sales', 'critic_score']].
    agg(['mean']).
    plot(
        ax=ax, 
        x=('total_sales','mean'), 
        y=('critic_score','mean')
    )
)
plt.legend(['X360', 'PS3']);
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг критиков')
plt.title('Зависимость рейтинга критиков от продаж PS3 и X360');
df[(df['platform']=='PS3')].plot(ax=ax, x='total_sales', y='critic_score', kind='scatter', color='orange', alpha=0.5);

# %%
# Построим график продаж и рейтинга пользователей

ax = (df.groupby('sales_X360_q')[['total_sales', 'user_score']].
    agg(['mean']).
    plot(
        x=('total_sales','mean'), 
        y=('user_score','mean')
    )
)
(
    df.groupby('sales_PS3_q')[['total_sales', 'user_score']].
    agg(['mean']).
    plot(
        ax=ax, 
        x=('total_sales','mean'), 
        y=('user_score','mean')
    )
)
plt.legend(['X360', 'PS3'])
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг пользователей')
plt.title('Зависимость рейтинга пользователей от продаж PS3 и X360');
df[(df['platform']=='PS3')].plot(ax=ax, x='total_sales', y='user_score', kind='scatter', color='orange', alpha=0.5);

# %% [markdown]
# По диаграммам рассеяния выраженной зависимости не наблюдается. Коэффициент Пирсона меньше 0,5.
# Зависимости между продажами платформ PS3 и X360 и рейтингом критиков или пользователей не обнаружено.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />на исследование определенное влияние оказывает заполнение пропусками ...

# %% [markdown]
# 2. Исследуем продажи/отзывы для платформ PS4, XOne.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />молодец, что сравниваешь влияние оценок на старых и «современных» для 2017 г. платформах

# %%
# построим диаграмму рассеяния рейтинга критиков
ax=df[(df['platform']=='XOne')].plot(x='total_sales', y='critic_score', kind='scatter')
df[(df['platform']=='PS4')].plot(ax=ax, x='total_sales', y='critic_score', kind='scatter', color='orange')
plt.legend(['XOne', 'PS4'])
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг критиков')
plt.title('Зависимость рейтинга критиков от продаж PS4 и XOne');

# %%
# построим диаграмму рассеяния рейтинга пользователей
ax=df[(df['platform']=='XOne')].plot(x='total_sales', y='user_score', kind='scatter')
df[(df['platform']=='PS4')].plot(ax=ax, x='total_sales', y='user_score', kind='scatter', color='orange')
plt.legend(['XOne', 'PS4'])
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг пользователей')
plt.title('Зависимость рейтинга пользователей от продаж PS4 и XOne');

# %%
df['total_sales'].corr(df['critic_score'].astype(float))
# Out:
# 0.245853277312419

# %%
# коэффициент корреляции рейтинга польователя и суммарными продажами платформы XOne
df[df['platform']=='XOne']['total_sales'].corr(df[df['platform']=='XOne']['user_score'])
# Out:
# -0.06892505328279415

# %%
# коэффициент корреляции рейтинга критиков и суммарными продажами платформы XOne
df[df['platform']=='XOne']['total_sales'].corr(df[df['platform']=='XOne']['critic_score'].astype(float))
# Out:
# 0.41699832800840164

# %%
# коэффициент корреляции рейтинга польователя и суммарными продажами платформы PS4
df[df['platform']=='PS4']['total_sales'].corr(df[df['platform']=='PS4']['user_score'])
# Out:
# -0.031957110204556424

# %%
# коэффициент корреляции рейтинга критиков и суммарными продажами платформы PS4
df[df['platform']=='PS4']['total_sales'].corr(df[df['platform']=='PS4']['critic_score'].astype(float))
# Out:
# 0.4065679020617816

# %% [markdown]
# По диаграмме рассеяния корреляции между рейтингом пользователей и критиков и суммарными продажам не наблюдается.
# Коэффициенты корреляции невысокие.
# Чтобы проверить зависимость продаж от рейтинга построим график зависимости средних продаж от средних рейтингов критиков и пользователей.

# %%
# построим корзины для продаж XOne и PS4
df['sales_XOne_q'] = pd.qcut(df[(df['platform']=='XOne')]['total_sales'],5)
df['sales_PS4_q'] = pd.qcut(df[(df['platform']=='PS4')]['total_sales'],5)

# Построим график продаж и рейтинга критиков
ax = (df.groupby('sales_XOne_q')[['total_sales', 'critic_score']].
    agg(['mean']).
    plot(
        x=('total_sales','mean'), 
        y=('critic_score','mean')
    )
)
(
    df.groupby('sales_PS4_q')[['total_sales', 'critic_score']].
    agg(['mean']).
    plot(
        ax=ax, 
        x=('total_sales','mean'), 
        y=('critic_score','mean')
    )
)
plt.legend(['XOne', 'PS4'])
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг критиков')
plt.title('Зависимость рейтинга критиков от продаж PS4 и XOne');
df[(df['platform']=='PS4')].plot(ax=ax, x='total_sales', y='critic_score', kind='scatter', color='orange', alpha=0.5);

# %%
# построим диаграмму рассеяния рейтинга пользователей
ax = (df.groupby('sales_XOne_q')[['total_sales', 'user_score']].
    agg(['mean']).
    plot(
        x=('total_sales','mean'), 
        y=('user_score','mean')
    )
)
(
    df.groupby('sales_PS4_q')[['total_sales', 'user_score']].
    agg(['mean']).
    plot(
        ax=ax, 
        x=('total_sales','mean'), 
        y=('user_score','mean')
    )
)
plt.legend(['XOne', 'PS4'])
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг пользователей')
plt.title('Зависимость рейтинга пользователей от продаж PS4 и XOne');
df[(df['platform']=='PS4')].plot(ax=ax, x='total_sales', y='user_score', kind='scatter', color='orange', alpha=0.5);

# %% [markdown]
# По диаграммам рассеяния выраженной зависимости для платформ PS4 и XOne не наблюдается. Коэффициент Пирсона меньше 0,5.
# Зависимости между продажами платформ PS34 и XOne и рейтингом критиков или пользователей не обнаружено.

# %% [markdown]
# 3. Исследуем продажи/отзывы для платформ PC.

# %%
# построим диаграмму рассеяния рейтинга критиков
df[(df['platform']=='PC') & (df['year_of_release']>=2013)].plot(x='total_sales', y='critic_score', kind='scatter')
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг критиков')
plt.title('Зависимость рейтинга критиков от продаж PC');

# %%
# построим диаграмму рассеяния рейтинга пользователей
df[(df['platform']=='PC') & (df['year_of_release']>=2013)].plot(x='total_sales', y='user_score', kind='scatter')
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг пользователей')
plt.title('Зависимость рейтинга пользователей от продаж PC');

# %%
# коэффициент корреляции рейтинга польователя и суммарными продажами платформы PC
df[(df['platform']=='PC') & (df['year_of_release']>=2013)]['total_sales'].corr(df[df['platform']=='PC']['user_score'])
# Out:
# -0.09384186952476739

# %%
# коэффициент корреляции рейтинга критиков и суммарными продажами платформы PC
df[(df['platform']=='PC') & (df['year_of_release']>=2013)]['total_sales'].corr(df[df['platform']=='PC']['critic_score'].astype(float))
# Out:
# 0.19603028294369382

# %% [markdown]
# По диаграмме рассеяния корреляции между рейтингом пользователей и критиков и суммарными продажам не наблюдается. Коэффициенты корреляции невысокие. Чтобы проверить зависимость продаж от рейтинга построим график зависимости средних продаж от средних рейтингов критиков и пользователей.

# %%
# построим корзины для продаж PC
df['sales_PC_q'] = pd.qcut(df[(df['platform']=='PC') & (df['year_of_release']>=2013)]['total_sales'],5)

# Построим график продаж и рейтинга критиков
ax = (
    df.groupby('sales_PC_q')[['total_sales', 'critic_score']].
    agg(['mean']).
    plot(
        x=('total_sales','mean'), 
        y=('critic_score','mean')
    )
)
plt.legend(["PC"])
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг критиков')
plt.title('Зависимость рейтинга критиков от продаж PC');
df[(df['platform']=='PC') & (df['year_of_release']>=2013)].plot(ax=ax, x='total_sales', y='critic_score', kind='scatter', color='orange');

# %%
df['total_sales'].corr(df['critic_score'].astype(float))
# Out:
# 0.245853277312419

# %%
# Построим график продаж и рейтинга пользователей
ax = (
    df.groupby('sales_PC_q')[['total_sales', 'user_score']].
    agg(['mean']).
    plot(
        x=('total_sales','mean'), 
        y=('user_score','mean')
    )
)
plt.legend(["PC"])
plt.xlabel('Суммарные продажи, млн')
plt.ylabel('Рейтинг пользователей')
plt.title('Зависимость рейтинга пользователей от продаж PC');
df[(df['platform']=='PC') & (df['year_of_release']>=2013)].plot(ax=ax, x='total_sales', y='user_score', kind='scatter', color='orange')
# Out:
# <AxesSubplot:title={'center':'Зависимость рейтинга пользователей от продаж PC'}, xlabel='total_sales', ylabel='user_score'>

# %% [markdown]
# По диаграммам рассеяния выраженной зависимости для платформ PC не наблюдается. Коэффициент Пирсона меньше 0,5.
# Зависимости между продажами платформы PC и рейтингом критиков или пользователей не обнаружено.

# %% [markdown]
# Для всех платформ нет зависимости между рейтингом пользователей и количеством продаж.

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Мы не принимаем в расчет показатель коэф. корреляции от -0,5 до +0,5, т.к. данные значения показывают слабую линейную зависимость...
#
# Стоит исправить очепятку
#
#         Для всех платформ есть зависимость между рейтингом пользователей и количеством продаж. Чем выше рейтинг, тем выше продажи. По рейтингу пользователей корреляции с продажами не наблюдается.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Очепятку и выводы исправил
#
# </div>

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Возможно пользователи более критичны к играм, чем критики, но мы не сможем оценить какие действия повлияли на рост продаж в рамках нашего проекта (ограниченность имеющихся данных)
#
#       Для всех платформ есть зависимость между рейтингом пользователей и количеством продаж. Чем выше рейтинг, тем выше продажи. По рейтингу пользователей корреляции с продажами не наблюдается.
#
# Приведу пример ложной корреляции, весьма известный в статистической литературе. Была исследована корреляционная связь между числом аистов, свивших гнезда в южных районах Швеции, и рождаемостью в эти же годы в Швеции. Расчёты, выполненные ради шутки, показали существенную положительную корреляцию между этими явлениями, хотя любому понятно, что это ложная корреляция.
#
# Ещё пример ложной корреляции между приемом на работу новых менеджеров и созданием новых производственных мощностей. Возможно, именно менеджеры являются «причиной» капиталовложений в новые производственные мощности? Или же, наоборот, создание новых производственных мощностей послужило «причиной» приема на работу новых менеджеров?
#
# Например, можно обнаружить сильную положительную связь (корреляцию) между разрушениями, вызванными пожаром, и числом пожарных, тушивших пожар. Следует ли заключить, что пожарные вызывают разрушения? Конечно, наиболее вероятное объяснение этой корреляции состоит в том, что размер пожара (внешняя переменная, которую забыли включить в исследование) оказывает влияние, как на масштаб разрушений, так и на числе привлеченных пожарных (т. е. чем больше пожар, тем большее количество пожарных вызывается на его тушение) .

# %% [markdown]
# ## Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
# продажи по всем жанрам
genres = (
    pd.DataFrame(
        df[df['year_of_release']>=2013].
        groupby('genre')['total_sales'].
        agg('sum').
        sort_values(ascending=False)
    )
)
genres
# Out:
#               total_sales
# genre
# Action             321.87
# Shooter            232.98
# Sports             150.65
# Role-Playing       145.89
# Misc                62.82
# Platform            42.63
# Racing              39.89
# Fighting            35.31
# Adventure           23.64
# Simulation          21.76
# Strategy            10.08
# Puzzle               3.17

# %%
# построим круговую диаграмму по жанрам
genres['total_sales'].plot.pie(figsize=(5,5), autopct='%1.1f%%', radius=1.5);

# %%
# построим круговые диаграммы по жанрам для ниаболее популярных платформ
pltf_list = ['PS3', 'X360', 'PS4', 'XOne', '3DS', 'PC']
fig, axs = plt.subplots(3,2,figsize=(15,15))
for i in list(range(6)):
    temp = (
        df[(df['year_of_release']>=2013) & 
           (df['platform']==pltf_list[i])].
        groupby('genre')['total_sales'].agg('sum').sort_values()
    )
    axs[round(i/2.1),i%2].pie(temp, labels=temp.index, autopct='%1.1f%%', radius=1.2)
    axs[round(i/2.1), i%2].set_title(pltf_list[i])

# %%
# построим график продаж жанров по платформам
y_offset =  df[(df['year_of_release']>=2013)].groupby('genre')['total_sales'].agg('sum').sort_values(ascending=False) * 0
data_temp = y_offset.copy()
pltf_list = ['PS3', 'X360', 'PS4', 'XOne', '3DS', 'PC']
for i in pltf_list:
    temp = (
        df[(df['year_of_release']>=2013) & 
           (df['platform']==i)].
        groupby('genre')['total_sales'].agg('sum')
    )
    temp = pd.concat([data_temp, temp], axis=1)
    temp.columns = ['first', 'total_sales']
    temp = temp['total_sales'].fillna(0)
    plt.bar(temp.index, temp, bottom=y_offset)
    y_offset = y_offset + temp
plt.legend(pltf_list)
plt.grid(True)
plt.xticks(rotation=90)
plt.title('Продажи по платформам');

# %%
# построим ящики с усами для каждой платформы без выбросов
sns.boxplot(
    x=df[(df['year_of_release']>=2013)]['genre'], 
    y=df[(df['year_of_release']>=2013)]['total_sales'],  
    order=data_temp.index,
    showfliers=False, 
    showmeans=True, 
    meanline=True
)
plt.grid(True)
plt.xlabel('Платформа')
plt.ylabel('Суммарные продажи');
plt.xticks(rotation=90)
plt.show()

# построим ящики с усами для каждой платформы с выбросами
sns.boxplot(
    x=df[(df['year_of_release']>=2013)]['genre'], 
    y=df[(df['year_of_release']>=2013)]['total_sales'],  
    order=data_temp.index,
    showfliers=True, 
    showmeans=True, 
    meanline=True
)
plt.grid(True)
plt.xlabel('Платформа')
plt.ylabel('Суммарные продажи');
plt.xticks(rotation=90);

# %% [markdown]
# Самые продаваемые игры по жанрам по общим продажам:
#
#         Action          321.87
#         Shooter         232.98
#         Sports          150.65
#
# Самые низкие продажи у жанров Puzzle, Strategy, Simulation.
# По платформам PS3, X360, PS4, XOne лидерами продаж также являются жанры Action, Shooter, Sports.
# Для платофрмы 3DS лидером продаж является жанр Role-Playing и Action. Для PC: Shooter, Simulation и Action.
# Медианные продажи для всех жанров разные. Меньший разброс имеет при больших продажах имеет Action. Также для этого жанра наблюдаются аномально большие продажи. Жанр Shooter имеет большой разброс продаж.

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит проанализировать прибыльность жанров на диаграмме размаха, сравнить медианные продажи на каждом жанре и проверить какая из них более стабильна и имеет более длинный ряд успешно продающихся игр
#
# График нарисовать в двух масштабах с выбросами и без (чтобы было видно 75 квартиль)
#
# Подправить выбор платформ
#
#         При этом на диаграмме продаж по платформам видно, что Wii

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Добавил диаграммы размаха. И исправил выбор платформ.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Диаграмма размаха показывает расположение медиан и квартилей на разных жанрах, шутер показывает самые уверенные результаты среди других платформ

# %% [markdown]
# ## Выводы

# %% [markdown]
# В данном разделе был проведен анализ данных по выпуску и продажам игр.
# Пик выпуска игр попадает на период 2007-2009гг, затем выпуск игр снижается. На пике выпускалось более 1400 игр в год. До 1993 года выпускалось мало игр.
# Для платформ характерна периодичность их существования. В среднем активное время существования платформы 10 лет.
# Для прогнозирования успешности игр был принят актуальный период между началом продаж PS4 и XOne: 2013 год до 2016 года.
# Были определены наиболее успешные платформы предыдущего поколения X360 и PS3. И потенциально прибыльные платформы - новые поколения игровых приставок PS4, XOne, портативная игровая система 3DS и персональные компьютеры PC.
# Зависимость между рейтингами пользоваетелей и критиков и продажами не наблюдается.
# Самые продаваемые игры по жанрам Action, Shooter и Sports. Самые низкие продажи у жанров Puzzle, Strategy, Simulation.
# Лидерами продаж за актуальный период являются PS4 и XOne.

# %% [markdown]
# # Составьте портрет пользователя каждого региона

# %% [markdown]
# ## Самые популярные платформы для каждого региона (топ-5). Опишите различия в долях продаж.

# %%
# соберем датафрейм с данными по платформам и продажам по регионам
region_df = (
    df[df['year_of_release']>=2013].
    pivot_table
    (
        index='platform', 
        values=['total_sales', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales'], 
        aggfunc='sum'
    ).
    sort_values('total_sales', ascending=False).
    head(5)
).reset_index()

# добавим строку с невошедшими топ-5 платформами
region_df = region_df.append(pd.DataFrame((df[df['year_of_release']>=2013].
    pivot_table
    (
        index='platform', 
        values=['total_sales', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales'], 
        aggfunc='sum'
    ).
    sort_values('total_sales', ascending=False).
    tail(-5)
).sum()).T, ignore_index = True).sort_values('total_sales', ascending=False).reset_index()
region_df['platform'] = region_df['platform'].fillna('Other')
region_df
# Out:
#    index platform  eu_sales  jp_sales  na_sales  other_sales  total_sales
# 0      0      PS4    141.09     15.96    108.74        48.35       314.14
# 1      1      PS3     67.81     23.35     63.50        26.77       181.43
# 2      2     XOne     51.59      0.34     93.12        14.27       159.32
# 3      5    Other     58.26     32.81     52.49        12.19       155.75
# 4      3      3DS     30.96     67.81     38.20         6.28       143.25
# 5      4     X360     42.52      0.51     81.66        12.11       136.80

# %%
# построим столбчатые диаграммы по продажам и платформам
y_offset = np.zeros(len(region_df))
region_list = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales']
for i in region_list:
    plt.bar(region_df['platform'], region_df[i], bottom=y_offset)
    y_offset = y_offset + region_df[i]
plt.legend(region_list)
plt.grid(True)
plt.xlabel('Платформы')
plt.ylabel('Продажи, млн')
plt.title('Суммарные продажи по каждой платформе');

# %% [markdown]
# PS4, PS3 и XOne - лидеры по продажам в мире. Больше всего покупателей в Америке и Европе.
# PS4 - лидер по продажам из современных платформ. Больше всего покупателей в Европе и Америке.
# XOne в Японии почти не продается.

# %%
#построим доли продаж платформ по регионам
fig, axs = plt.subplots(1,4,figsize=(15,5))
axs[0].pie(region_df['eu_sales'], labels=region_df['platform'], autopct='%1.1f%%', radius=1)
axs[1].pie(region_df['na_sales'], labels=region_df['platform'], autopct='%1.1f%%', radius=1)
axs[2].pie(region_df['jp_sales'], labels=region_df['platform'], autopct='%1.1f%%', radius=1)
axs[3].pie(region_df['other_sales'], labels=region_df['platform'], autopct='%1.1f%%', radius=1)
axs[0].set_title('Европа')
axs[1].set_title('Америка')
axs[2].set_title('Япония')
axs[3].set_title('Остальные регионы')
fig.suptitle('Доли продаж платформ по регионам');

# %% [markdown]
# В Европе лидеры продаж PS4 - 36% и PS3 - 17%.
# В Америке лидеры продаж PS4 - 25% и XOne - 21%.
# В Японии лидер продаж портативная система 3DS - 48% и остальные платформы - 23%. А по приставкам: PS4 - 11% и PS3 - 17%.
# В остальном мире лидер продаж PS4 - 40%.
# Пользователи из Японии предпочитают портативные игровые системы и платформы японских разработчиков.
# Во всем мире, кроме Японии, лидером продаж является PS4.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Классное графическое сопровождение своих выводов
#
# Стоит добавить
#
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Добавил заголовок графиков.
# Добавил категорию "другие".
#
# </div>

# %% [markdown]
# ## Самые популярные жанры (топ-5). Поясните разницу.

# %%
# построим датафрейм с данными по жанрам и продажам по регионам
genre_df = (
    df[df['year_of_release']>=2013].
    pivot_table
    (
        index='genre', 
        values=['total_sales', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales'], 
        aggfunc='sum'
    ).
    sort_values('total_sales', ascending=False).
    head(5)
).reset_index()

# добавим строку с невошедшими топ-5 жанрами
genre_df = genre_df.append(pd.DataFrame(
    (df[df['year_of_release']>=2013].
        pivot_table
        (
            index='genre', 
            values=['total_sales', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales'], 
            aggfunc='sum'
        ).
        sort_values('total_sales', ascending=False).
        tail(-5)
    ).sum()).T, ignore_index = True).sort_values('total_sales', ascending=False).reset_index()
genre_df['genre'] = genre_df['genre'].fillna('Other')
genre_df
# Out:
#    index         genre  eu_sales  jp_sales  na_sales  other_sales  total_sales
# 0      0        Action    118.13     40.49    126.05        37.20       321.87
# 1      1       Shooter     87.86      6.61    109.74        28.77       232.98
# 2      5         Other     68.71     28.03     62.76        16.98       176.48
# 3      2        Sports     60.52      5.41     65.27        19.45       150.65
# 4      3  Role-Playing     36.97     51.04     46.40        11.48       145.89
# 5      4          Misc     20.04      9.20     27.49         6.09        62.82

# %%
# построим столбчатые диаграммы по продажам и платформам
y_offset = np.zeros(len(genre_df))
pltf_list = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales']
for i in pltf_list:
    plt.bar(genre_df['genre'], genre_df[i], bottom=y_offset)
    y_offset = y_offset + genre_df[i]
plt.legend(pltf_list)
plt.grid(True)
plt.xlabel('Жанры')
plt.ylabel('Продажи, млн')
plt.title('Суммарные продажи по каждому жанру');

# %% [markdown]
# Самый продаваемый жанр Action с наибольшими продажами в Америке и Европе.
# Наименьшие продажи у жанра Misc.
# Самым популярным жанром в Японии является Role-Playing.

# %%
#построим доли продаж жанров по регионам
fig, axs = plt.subplots(1,4,figsize=(15,5))
axs[0].pie(genre_df['eu_sales'], labels=genre_df['genre'], autopct='%1.1f%%', radius=1)
axs[1].pie(genre_df['na_sales'], labels=genre_df['genre'], autopct='%1.1f%%', radius=1)
axs[2].pie(genre_df['jp_sales'], labels=genre_df['genre'], autopct='%1.1f%%', radius=1)
axs[3].pie(genre_df['other_sales'], labels=genre_df['genre'], autopct='%1.1f%%', radius=1)
axs[0].set_title('Европа')
axs[1].set_title('Америка')
axs[2].set_title('Япония')
axs[3].set_title('Остальные регионы')
fig.suptitle('Доли продаж жанров по регионам');

# %% [markdown]
# Во всем мире, кроме Японии, лидерами продаж являются жанры Action и Shooter.
# В Японии лидером продаж является Role-Playing и Action. Жанры Sport и Shooter не популярны.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Дублирую
#
# Стоит добавить
#
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Добавил заголовок графиков.
# Добавил категорию "другие".
#
# </div>

# %% [markdown]
# ## Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
# построим датафрейм с данными по рейтингу и продажам по регионам
rating_df = (
    df[df['year_of_release']>=2013].
    pivot_table
    (
        index='rating', 
        values=['total_sales', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales'], 
        aggfunc='sum'
    ).
    sort_values('total_sales', ascending=False).
    head(5)
).reset_index()
rating_df
# Out:
#   rating  eu_sales  jp_sales  na_sales  other_sales  total_sales
# 0      M    145.32     14.11    165.21        47.04       371.68
# 1     RP     78.91     85.05     89.42        23.46       276.84
# 2      E     83.36     15.14     79.05        22.61       200.16
# 3      T     41.95     20.59     49.79        14.29       126.62
# 4   E10+     42.69      5.89     54.24        12.57       115.39

# %% [markdown]
# «E» («Everyone») — «Для всех»
# «M» («Mature») — «Для взрослых»
# «T» («Teen») — «Подросткам»
# «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»
# «EC» («Early childhood») — «Для детей младшего возраста»
# «RP» («Rating Pending») — «Рейтинг ожидается»

# %%
# Проверим невошедшие в топ-5 рейтинги
(df[df['year_of_release']>=2013].pivot_table
    (
        index='rating', 
        values=['total_sales', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales'], 
        aggfunc='sum'
    ).
    sort_values('total_sales', ascending=False).
    tail(-5)).sum()
# Out:
# eu_sales       0.0
# jp_sales       0.0
# na_sales       0.0
# other_sales    0.0
# total_sales    0.0
# dtype: float64

# %% [markdown]
# Список рейтингов за исследуемый период состоит всего из пяти позиций. Остальные рейтинги вне исслдеуемого диапазона.

# %%
# построим столбчатые диаграммы по рейтингу продажам
y_offset = np.zeros(len(rating_df))
region_list = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales']
for i in region_list:
    plt.bar(rating_df['rating'], rating_df[i], bottom=y_offset)
    y_offset = y_offset + rating_df[i]
plt.legend(region_list)
plt.grid(True)
plt.xlabel('Рейтинг')
plt.ylabel('Продажи, млн')
plt.title('Суммарные продажи по рейтингам');

# %% [markdown]
# Наиболее продаваемые игры с рейтингом M - "для взрослых".

# %%
#построим доли продаж рейтингов по регионам
fig, axs = plt.subplots(1,4,figsize=(15,5))
axs[0].pie(rating_df['eu_sales'], labels=rating_df['rating'], autopct='%1.1f%%', radius=1)
axs[1].pie(rating_df['na_sales'], labels=rating_df['rating'], autopct='%1.1f%%', radius=1)
axs[2].pie(rating_df['jp_sales'], labels=rating_df['rating'], autopct='%1.1f%%', radius=1)
axs[3].pie(rating_df['other_sales'], labels=rating_df['rating'], autopct='%1.1f%%', radius=1)
axs[0].set_title('Европа')
axs[1].set_title('Америка')
axs[2].set_title('Япония')
axs[3].set_title('Остальные регионы')
fig.suptitle('Доли продаж рейтингов по регионам');

# %% [markdown]
# Лидер продаж игры с рейтингом М в мире, кроме Японии.
# В Японии лидируют продажи игр с рейтингом RP. Возможно, это игры были выпущены в Японии и не имеют рейтинга по классификации ESRB.

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# При твоем способе подсчета игры без рейтинга оказываются почти полностью исключенными из анализа. Но продажи именно этих игр могут указать на ключевое различие в регионах
#
# Стоит поработать со столбцом рейтингов, заменить пропуски, посмотреть на частотность использования всех категорий рейтинга

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Дублирую
#
# Стоит добавить
#
# + оформить "двухуровневый заголовок" - и у всех трех графиков вместе;
# + при анализе платформ и жанров стоит все, что не вошло в ТОП-5, объединять в категорию "другие" - так картина анализа будет более полной.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Добавил заголовок графиков.
# Категорию "другие" не добавил, т.к. список за актуальный период состоит всего из пяти рейтингов.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />да все верно, это я перестарался :)

# %% [markdown]
# ## Выводы

# %% [markdown]
# Во всем мире, кроме Японии, лидером продаж среди платформ является PS4.
# Во всем мире, кроме Японии, лидерами продаж являются жанры Action и Shooter.
# По рейтингу ESRP наиболее продаваемые игры с рейтингом М во всем мире, кроме Японии.
# Пользователи из Японии предпочитают исключительно платформы японских разработчиков PS3, PS4 и 3DS.
# В Японии лидером продаж является Role-Playing и Action, а жанры Sport и Shooter не популярны.

# %% [markdown]
# # Проверка гипотез

# %% [markdown]
# ## Средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# Нулевая гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC равны.
# Альтернативная гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC не равны.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> гипотезы сформулированы верно

# %%
# критический уровень статистической значимости
alpha = 0.05

# Т-тест о равенстве средних двух выборок
# платформа Xbox One была выпущена в 2013 году, поэтому сравниваем выборки за одинаковый период
results = st.ttest_ind(
    df[df['platform']=='XOne']['user_score'].dropna(),
    df[(df['platform']=='PC') & (df['year_of_release']>=2013)]['user_score'].dropna(),
    equal_var = False 
)

print(
    'Средний рейтинг платформы Xbox One:', 
    df[df['platform']=='XOne']['user_score'].mean()
)
print(
    'Средний рейтинг платформы PC:', 
    df[df['platform']=='PC']['user_score'].mean()
)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Средний рейтинг платформы Xbox One: 6.521428571428572
# Средний рейтинг платформы PC: 7.065960264900661
# p-значение: 0.14759594013430463
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Полученное Р-значение больше уровня статистической значимости. Т.е. вероятность получить такое или большее различие между средними случайно почти 15% и гипотеза о равенстве между средними пользовательскими рейтингами платформ Xbox One и PC не может быть отвергнута.

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Что означает на языке статистики p-значение: 0.07095126181253582
#
#         Т.е. вероятность получить равные средние рейтинги равна 7%, значит средние рейтинги пользователей платформ PC и Xbox One могут быть равны.
#
# Стоит откорректировать

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Вывод откорректировал
#
# </div>

# %% [markdown]
# ## Средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# Нулевая гипотеза: Средние пользовательские рейтинги жанров Action и Sports равны.
# Альтернативная гипотеза: Средние пользовательские рейтинги жанров Action и Sports не равны.

# %%
# критический уровень статистической значимости
alpha = 0.05

# Т-тест о равенстве средних двух выборок
results = st.ttest_ind(
    df[(df['genre']=='Action') & (df['year_of_release']>=2013)]['user_score'].dropna(),
    df[(df['genre']=='Sports') & (df['year_of_release']>=2013)]['user_score'].dropna(),
    equal_var = False 
)

print(
    'Средний рейтинг жанра Action:', 
    df[df['genre']=='Action']['user_score'].mean()
)
print(
    'Средний рейтинг жанра Sports:', 
    df[df['genre']=='Sports']['user_score'].mean()
)

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Средний рейтинг жанра Action: 7.058129175946546
# Средний рейтинг жанра Sports: 6.959466911764705
# p-значение: 1.4460039700704315e-20
# Отвергаем нулевую гипотезу

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#     results = st.ttest_ind(
#         df[df['genre']=='Action']['user_score'],
#         df[df['genre']=='Sports']['user_score'],
#         equal_var = False
#     )
#
# Для расчетов выбран неактуальный датасет, стоит откорректировать

# %% [markdown]
# Полученное значение p-value меньше уровня статистической значимости. Т.е. маловероятна случайность полученных результатов, что дает основание отвергнуть гипотезу, что средние рейтинги пользователей жанров Action и Sports равны.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Датасет актуализировал и вывод откорректировал.
#
# Я правильно понимаю, что проводя т-тест мы никогда не можем утверждать, что средние двух выборок равны?
# Результат, который мы можем получить:
#     либо средние не равны, если р-значение меньше альфа,
#     либо, если р-значение больше альфа, средние могут быть равны, а могут быть не равны.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />оставлю примеры, там есть тонкости с вероятностью получить разницу случайно

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Приведу пример и теорию для понимания формулировок и интерпретации итогов проведения гипотез</b>
#
#
# Задача. Приведены два датасета: сумма покупок, совершённых за месяц посетителями, привлечёнными по двум разным каналам. В вашем распоряжении случайная выборка из 30 покупок для каждого канала.
#
# H0 - средние чеки равны
#
#
# H1 - средние чеки НЕ равны
#
# Да сама формулировка нулевой и альтернативной гипотезы звучит именно так, но результат теста интерпретируется другими словами
#
#
# <b>Из теории на тренажере</b>
#
# Формулирование двусторонних гипотез. <br>
#
# <b>Никакие экспериментально полученные данные никогда не подтвердят какую-либо гипотезу. Это наше фундаментальное ограничение. </b>Данные могут лишь не противоречить ей или, наоборот, показывать крайне маловероятные результаты (при условии, что гипотеза верна). Но и в том, и в другом случае нет оснований утверждать, что выдвинутая гипотеза доказана.
# Допустим, данные гипотезе не противоречат, тогда мы её не отвергаем. Если же мы приходим к выводу, что получить такие данные в рамках этой гипотезы вряд ли возможно, у нас появляется основание отбросить эту гипотезу.
#
# P-значение (англ. P-value) — величина, используемая при тестировании статистических гипотез. <b>Фактически это вероятность ошибки при отклонении нулевой гипотезы (ошибки первого рода)</b> пример ниже

# %%
# Приведены два датасета: сумма покупок, совершённых за месяц посетителями ...

sample_1 = [3071, 3636, 3454, 3151, 2185, 3259, 1727, 2263, 2015,
2582, 4815, 633, 3186, 887, 2028, 3589, 2564, 1422, 1785,
3180, 1770, 2716, 2546, 1848, 4644, 3134, 475, 2686,
1838, 3352]
sample_2 = [1211, 1228, 2157, 3699, 600, 1898, 1688, 1420, 5048, 3007,
509, 3777, 5583, 3949, 121, 1674, 4300, 1338, 3066,
3562, 1010, 2311, 462, 863, 2021, 528, 1849, 255,
1740, 2596]
alpha = .05 # критический уровень статистической значимости
# если p-value окажется меньше него - отвергнем гипотезу
results = st.ttest_ind(
sample_1,
sample_2)
print('p-значение:', results.pvalue)
if (results.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:

    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.1912450522572209
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Интерпретация результата:
#
# Полученное значение p-value говорит о том, что хотя средний чек пришедших из разных каналов и неодинаков, <b>с вероятностью в почти 19% такое или большее различие можно получить случайно. </b>Это явно слишком большая вероятность, чтобы делать вывод о значимом различии между средними чеками.
#
# А если p-value  будет равно 0,9999, то это значит, что с вероятностью почти 100% <u>такое различие</u> можно получить случайно — то есть никогда :)

# %% [markdown]
# # Общий вывод

# %% [markdown]
# С целью выявить определяющие успешность игры закономерности были исследованы параметры популярности компьютерных игр и выполнены следующие задачи:
# - считаны и изучены данные из исходных файлов;
# - подготовлены данные: изменены названия столбцов, преобразованы данные в нужные типы, обработаны пропуски;
# - проведен исследовательский анализ данных: сколько игр выпускалось в разные годы, как менялись продажи по платформам, определен актуальный период, определены лидирующие платформы по продажам, построен график «ящик с усами» по глобальным продажам игр, проведен анализ, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков, изучено общее распределение игр по жанрам,
# - составлен портрет пользователя каждого региона: определены самые популярные платформы,  определены самые популярные жанры, исследовано влияние рейтинга ESRB на продажи в отдельном регионе;
# - проверены гипотезы:
#     - средние пользовательские рейтинги платформ Xbox One и PC одинаковые
#     - средние пользовательские рейтинги жанров Action и Sports разные.
# - написан общий вывод.
#
# По результатам анализа данных по выпуску и продажам игр было определено, что пик выпуска игр попадает на период 2007-2009гг, затем выпуск игр снижается. На пике выпускалось более 1400 игр в год. До 1993 года выпускалось мало игр.
# Для платформ характерна периодичность их существования. В среднем активное время существования платформы 10 лет.
# Для прогнозирования успешности игр был принят актуальный период между началом продаж PS4 и XOne: с 2013 по 2016 год.
# Были определены наиболее успешные платформы предыдущего поколения X360 и PS3. И потенциально прибыльные платформы - новые поколения игровых приставок PS4, XOne, портативные игровые системы 3DS и персональные компьютеры PC.
# Зависимости между рейтингами пользователей и критиков и продажами не наблюдается.
# Самые продаваемые игры по жанрам Action, Shooter и Sports. Самые низкие продажи у жанров Puzzle, Strategy, Simulation.
# Лидерами продаж за актуальный период являются PS4 и XOne.
#
# По результатам анализа продаж игр по регионам было обнаружено, что во всем мире, кроме Японии, лидером продаж является PS4.
# Во всем мире, кроме Японии, лидерами продаж являются жанры Action, Shooter и Sport.
# По рейтингу ESRP наиболее продаваемые игры с рейтингом М во всем мире, кроме Японии.
# Пользователи из Японии предпочитают исключительно платформы японских разработчиков PS3, PS4 и 3DS.
# В Японии лидером продаж является Role-Playing и Action, а жанры Sport и Shooter не популярны.
#
# Таким образом по результатам проведеннго анализа, следует, что потенциально успешным будет продукт, выпущенный для платформы PS4, в жанре Action с рейтингом M.

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
#
# Откорректировал вывод после внесения исправлений по ходу анализа.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Технически вывод составлен замечательно, сравниваешь регионы, представлены числовые показатели, открыты инсайты различных рынков
#
# стоит подправить некоторые моменты после исправления ❌ комментариев в проекте

# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#  Замечательный и ясный проект, наполненный исследованиями, красиво и полностью оформленными графиками, с использованием автоматизированных блоков кода, молодец
#
# Критические ❌ комментарии связаны с неточностями:
#
#  + вернуть пропуски в столбцы оценок
#  + заполнить пропуски в столбце рейтингов
#  + сократить категории в рейтингах (на твое усмотрение)
#  + пересмотреть перечень актуальных платформ
#  + оценить прибыльность жанров на диаграмме размаха
#  + оформить и изменить графики в ТОП-5 (на твое усмотрение), перепроверить выводы после исправления неточностей (рейтинг)
#  + перепроверить промежуточные и итоговый выводы после исправлений
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5", color= "seagreen"><b>Жду твой проект и твои комментарии 🤝</b></font><br />

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Может пригодиться
#
# [Подборка статей о работе с библиотеками для анализа данных на языке Python](https://dfedorov.spb.ru/pandas/)
#
# [Искусство статистики](https://www.mann-ivanov-ferber.ru/books/iskusstvo-statistiki/)
#
# [Постер «Графики, которые убеждают всех»](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)
#
#
# В помощь — как реализовать интерактивный план проекта вручную (для собственных проектов), смотри по <a href="https://stackoverflow.com/questions/49535664/how-to-hyperlink-in-a-jupyter-notebook/49717704">ссылке</a>
#
# пара ссылок и по разделам проекта можно будет переходить без пролистывания всего кода, особенно актуально на проектах длина которых >  10 страниц (и там где не установлен плагин TOC)
