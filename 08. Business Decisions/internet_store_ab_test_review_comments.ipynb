# %% [markdown]
# Привет Евгений :) Меня зовут Семенюк Артём, я буду проверять твой проект. Предлагаю общаться на "ты",
# если так не очень комфортно, то перейдём на "Вы".
# Несколько слов о ревью. Оно может содержать 3 типа комментариев, различающихся цветом:
#
# <div class="alert alert-success">
# ✅Зелёный: хорошие решения и верные выводы, которые могут быть применены в будущем, интересные подходы
# </div>
#
#
# <div class="alert alert-warning">
# ⚠️Жёлтый: не критические замечания тех моментов, которые можно реализовать по-другому или оптимировать (исправлять их сейчас не обязательно, но стоит прокомментировать)
# </div>
#
#
# <div class="alert alert-danger">
# ❌Красный: аспекты заданий, требующие твоего непосредственного внимания (при их исправлении
# проект будет принят)
# </div>
#
#
# Предлагаю работать над проектом в диалоге. Если что-то меняешь в проекте следуя моим рекомендациям, то
# выделяй, пожалуйста, свои комментарии, отличным от моих цветом. И так же большая просьба
# не изменять и не удалять мои комментарии. Так будет проще отслеживать изменения в проекте
# и это ускорит повторную проверку :)

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b>
#
# Привет, Артём! Спасибо за проверку и комментарии.
#
# Устранил следующие замечания:
#
# - Добавил описание разделов в разделах 3 и 4.
# - Добавил описание отличия методов ICE и RICE.
# - Добавил изначальное количество пользователей в группах и оценил период проведения теста.
# - Добавил постановку гипотез.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера 2:</b> Привет, все замечания исправлены верно. Прошу прощения не заметил при первой проверке одну неточность при вычсилении кол-ва пользователей в группе, останоь уточнить только этот момент :)
# </div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента 2:</b> Поправил расчет уникальных пользователей.</div>

# %% [markdown]
# # Проверка гипотез и анализ результатов А/В теста

# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Общая-информация" data-toc-modified-id="Общая-информация-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Общая информация</a></span></li><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Часть.1-Приоритезация-гипотез." data-toc-modified-id="Часть.1-Приоритезация-гипотез.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Часть.1 Приоритезация гипотез.</a></span><ul class="toc-item"><li><span><a href="#Примените-фреймворк-ICE-для-приоритизации-гипотез.-Отсортируйте-их-по-убыванию-приоритета." data-toc-modified-id="Примените-фреймворк-ICE-для-приоритизации-гипотез.-Отсортируйте-их-по-убыванию-приоритета.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Примените фреймворк ICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.</a></span></li><li><span><a href="#Примените-фреймворк-RICE-для-приоритизации-гипотез.-Отсортируйте-их-по-убыванию-приоритета." data-toc-modified-id="Примените-фреймворк-RICE-для-приоритизации-гипотез.-Отсортируйте-их-по-убыванию-приоритета.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Примените фреймворк RICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Часть-2.-Анализ-A/B-теста" data-toc-modified-id="Часть-2.-Анализ-A/B-теста-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Часть 2. Анализ A/B-теста</a></span><ul class="toc-item"><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Постройте-график-кумулятивной-выручки-по-группам.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-кумулятивной-выручки-по-группам.-Сделайте-выводы-и-предположения.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-кумулятивного-среднего-чека-по-группам.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-кумулятивного-среднего-чека-по-группам.-Сделайте-выводы-и-предположения.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-относительного-изменения-кумулятивного-среднего-чека-группы-B-к-группе-A.-Сделайте-выводы-и-предположения.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-кумулятивной-конверсии-по-группам.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-кумулятивной-конверсии-по-группам.-Сделайте-выводы-и-предположения.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Постройте график кумулятивной конверсии по группам. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-график-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-график-относительного-изменения-кумулятивной-конверсии-группы-B-к-группе-A.-Сделайте-выводы-и-предположения.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Постройте график относительного изменения кумулятивной конверсии группы B к группе A. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Постройте-точечный-график-количества-заказов-по-пользователям.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-точечный-график-количества-заказов-по-пользователям.-Сделайте-выводы-и-предположения.-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберите-границу-для-определения-аномальных-пользователей." data-toc-modified-id="Посчитайте-95-й-и-99-й-перцентили-количества-заказов-на-пользователя.-Выберите-границу-для-определения-аномальных-пользователей.-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.</a></span></li><li><span><a href="#Постройте-точечный-график-стоимостей-заказов.-Сделайте-выводы-и-предположения." data-toc-modified-id="Постройте-точечный-график-стоимостей-заказов.-Сделайте-выводы-и-предположения.-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-95-й-и-99-й-перцентили-стоимости-заказов.-Выберите-границу-для-определения-аномальных-заказов." data-toc-modified-id="Посчитайте-95-й-и-99-й-перцентили-стоимости-заказов.-Выберите-границу-для-определения-аномальных-заказов.-4.10"><span class="toc-item-num">4.10&nbsp;&nbsp;</span>Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-конверсии-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения.-4.11"><span class="toc-item-num">4.11&nbsp;&nbsp;</span>Посчитайте статистическую значимость различий в конверсии между группами по «сырым» данным. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«сырым»-данным.-Сделайте-выводы-и-предположения.-4.12"><span class="toc-item-num">4.12&nbsp;&nbsp;</span>Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-конверсии-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения.-4.13"><span class="toc-item-num">4.13&nbsp;&nbsp;</span>Посчитайте статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения." data-toc-modified-id="Посчитайте-статистическую-значимость-различий-в-среднем-чеке-заказа-между-группами-по-«очищенным»-данным.-Сделайте-выводы-и-предположения.-4.14"><span class="toc-item-num">4.14&nbsp;&nbsp;</span>Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.</a></span></li><li><span><a href="#Примите-решение-по-результатам-теста-и-объясните-его." data-toc-modified-id="Примите-решение-по-результатам-теста-и-объясните-его.-4.15"><span class="toc-item-num">4.15&nbsp;&nbsp;</span>Примите решение по результатам теста и объясните его.</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Общая информация

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)
#
# **Входные данные:**
#
#     Файл /datasets/hypothesis.csv с гипотезами.
#     Файл /datasets/orders.csv и /datasets/visitors.csv с результатами А/В теста.
#
# **Цель:** Приоритизируйте гипотезы, запустите A/B-тест и проанализируйте результаты.
#
# **Задачи:**
# **Часть 1. Приоритизация гипотез.**
# В файле `/datasets/hypothesis.csv` 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами `Reach`, `Impact`, `Confidence`, `Effort`.
# - Примените фреймворк `ICE` для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# - Примените фреймворк `RICE` для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# - Укажите, как изменилась приоритизация гипотез при применении `RICE` вместо `ICE`. Объясните, почему так произошло.
#
# **Часть 2. Анализ A/B-теста**
# Вы провели A/B-тест и получили результаты, которые описаны в файлах `/datasets/orders.csv` и `/datasets/visitors.csv`.
#
# Проанализируйте A/B-тест:
# 1. Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.
# 2. Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.
# 3. Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.
# 4. Постройте график кумулятивной конверсии по группам. Сделайте выводы и предположения.
# 5. Постройте график относительного изменения кумулятивной конверсии группы B к группе A. Сделайте выводы и предположения.
# 6. Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.
# 7. Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.
# 8. Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.
# 9. Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.
# 10. Посчитайте статистическую значимость различий в конверсии между группами по «сырым» данным. Сделайте выводы и предположения.
# 11. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.
# 12. Посчитайте статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделайте выводы и предположения.
# 13. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.
# 14. Примите решение по результатам теста и объясните его. Варианты решений: 1. Остановить тест, зафиксировать победу одной из групп. 2. Остановить тест, зафиксировать отсутствие различий между группами. 3. Продолжить тест.

# %% [markdown]
# ## Обзор данных

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %%
import pandas as pd
import scipy.stats as stats
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **1. Чтение данных `hypothesis`**

# %%
# чтение данных
hypothesis = pd.read_csv('/datasets/hypothesis.csv')

# %%
# информация по датафрейму
hypothesis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes

# %%
# приведем названия столбцов к нижнему регистру
hypothesis.columns = hypothesis.columns.str.lower()

# %%
# проверка дубликатов строк
hypothesis.duplicated().sum()
# Out:
# 0

# %%
hypothesis
# Out:
#                                           hypothesis  reach  impact  \
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 1  Запустить собственную службу доставки, что сок...      2       5
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
# 5  Добавить страницу отзывов клиентов о магазине,...      3       2
# 6  Показать на главной странице баннеры с актуаль...      5       3
# 7  Добавить форму подписки на все основные страни...     10       7
# 8  Запустить акцию, дающую скидку на товар в день...      1       9
#
#    confidence  efforts
# 0           8        6
# 1           4       10
# 2           7        3
# 3           3        8
# 4           1        1
# 5           2        3
# 6           8        3
# 7           8        5
# 8           9        5

# %% [markdown]
# В таблице `hypothesis` девять записей.
# Пропусков и дубликатов не обнаружено.
# Тип данных в столбцах задан верно.
# Названия столбцов были приведены к нижнему регистру в соответствии со стилистическими нормами.

# %% [markdown]
# **2. Чтение данных `orders`**

# %%
# чтение данных
orders = pd.read_csv('/datasets/orders.csv')

# информация по датафрейму
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB

# %%
# переименование столбцов
orders.columns = ['order_id', 'user_id', 'date', 'revenue', 'group']

# перобразование даты
orders['date'] = pd.to_datetime(orders['date'])

orders.head()
# Out:
#      order_id     user_id       date  revenue group
# 0  3667963787  3312258926 2019-08-15     1650     B
# 1  2804400009  3642806036 2019-08-15      730     B
# 2  2961555356  4069496402 2019-08-15      400     A
# 3  3797467345  1196621759 2019-08-15     9759     B
# 4  2282983706  2322279887 2019-08-15     2308     B

# %%
# проверка дубликатов строк
orders.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В таблице `orders` 1197 записей.
# Пропусков и дубликатов не обнаружено.
# Тип данных в столбце `date` был заменен с `object` на `datetime`. Остальные типы данных оставлены как есть.
# Названия столбцов были приведены к нижнему регистру в соответствии со стилистическими нормами.

# %% [markdown]
# **3. Чтение данных `visitors`**

# %%
# чтение данных
visitors = pd.read_csv('/datasets/visitors.csv')

# информация по датафрейму
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
# перобразование даты
visitors['date'] = pd.to_datetime(visitors['date'])

visitors.head()
# Out:
#         date group  visitors
# 0 2019-08-01     A       719
# 1 2019-08-02     A       619
# 2 2019-08-03     A       507
# 3 2019-08-04     A       717
# 4 2019-08-05     A       756

# %%
# проверка дубликатов строк
visitors.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В таблице `visitors` 62 записи.
# Пропусков и дубликатов не обнаружено.
# Тип данных в столбце `date` был заменен с `object` на `datetime`. Остальные типы данных оставлены как есть.
# Названия столбцов соответствуют стилистическим нормам.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Всё здорово. Для удобства просмотра данных, можно реализовать универсальную функцию, например такую:
#
#     def f(df):
#         df.info()
#         df.duplicated().sum()
#         ...
#
# :)
# </div>

# %% [markdown]
# ## Часть.1 Приоритезация гипотез.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# В данном разделе приведена оценка рейтингов гипотез, которые могут способствовать увеличению выручки интернет-магазина. Оценка рейтингов гипотез будет проведена методами ICE и RICE. По результатам оценки рейтингов следует выбрать наиболее приоритетные гипотезы для проведения исследования.

# %% [markdown]
# ### Примените фреймворк ICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# В данном разделе определим рейтинги гипотез методом ICE по параметрам impact, confidence, effort из таблицы hypothesis. Гипотезы, которые наберут наибольшие рейтинги, следует рассматривать приоритетными.

# %% [markdown]
# <div class="alert alert-block alert-warning"> ⚠️ <b>Комментарий ревьюера:</b> Здесь было бы здорово добавить небольшое описание. Что будет исследоваться, для чего и т.п. </div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b> Добавил описание раздела.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Отлично   :)
# </div>

# %%
# расчитаем приоритет методом ICE
hypothesis['ICE'] = round(hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts'], 2)

pd.options.display.max_colwidth = 150
display(hypothesis[['hypothesis', 'ICE']].sort_values(by='ICE', ascending=False))
# Out:
#                                                                                                      hypothesis  \
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Здорово, что получилось вывести названия гипотез целиком. Но рекомендую вместо print использовать display, так вывод будет более привычным и удобным  :)
# </div>

# %% [markdown]
# Наиболее перспективные гипотезы по ICE: 8, 0 и 7

# %% [markdown]
# ### Примените фреймворк RICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# В данном разделе определим рейтинги гипотез методом RICE по параметрам reach, impact, confidence, effort из таблицы hypothesis. Гипотезы, которые наберут наибольшие рейтинги, следует рассматривать приоритетными.

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b> Добавил описание раздела.</div>

# %%
# расчитаем приоритет методом RICE
hypothesis['RICE'] = hypothesis['reach'] * hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts']

display(hypothesis[['hypothesis','RICE']].sort_values(by='RICE', ascending=False))
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# Наиболее перспективные гипотезы по RICE: 7, 2, 0 и 6. Гипотезы 0 и 6 имеют одинаковый рейтинг.

# %% [markdown]
# ### Выводы

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# Были проанализированы приоритеты гипотез методами ICE и RICE.
# Наиболее перспективные гипотезы по ICE: 8, 0 и 7.
# Наиболее перспективные гипотезы по RICE: 7, 2, 0 и 6.
# Лидерами по RICE стали гипотезы 7 и 2, т.к. имеют наибольший охват аудитории. Гипотезы 0 и 7 попали в лидеры обоих методов, т.к. имеют высокие рейтинги влияния на пользователей и высокий рейтинг уверенности в данной оценке. Затраты на проверку каждой гипотезы средние: для 7 - 5, для 2 - 3, для 0 - 6. Гипотезу 6 отбрасываем из-за низкого влияния на пользователей - рейтинг 3, а гипотезу 8 отбрасываем из-за низкого охвата аудитории - рейтинг 1.
# Различие наборов гипотез связано с тем, что, в отличие от RICE, ICE не учитывает параметр Reach - охват пользователей.
# При наличии возможности предпочтительнее использовать RICE.
# Наиболее перспективные гипотезы по результатам анализа:
#     7. Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок.
#     2. Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа.
#     0. Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей.

# %% [markdown]
# <div class="alert alert-block alert-danger">❌ <b>Комментарий ревьюера:</b> Всё здорово. Но из этого вывода не очень понятно чем же отличаются данные методы и почему получены разные результаты
# </div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b> Добавил описание отличия методов.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Супер, теперь ясно в чём отличие методов и почему получены разные результаты  :)
# </div>

# %% [markdown]
# ## Часть 2. Анализ A/B-теста

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# В данном разделе проведен анализ результатов проведенного А/В теста. Результаты анализа помогут компании понять, следует ли внедрить изменения, сохранить исходное состояние продукта или, возможно, проводить эксперимент дольше, чтобы принять решение.

# %% [markdown]
# <div class="alert alert-block alert-warning"> ⚠️ <b>Комментарий ревьюера:</b>Здесь тоже можно добавить небольшое описание. Какие задачи будут рещаться. Как они могут быть полезны бизнесу </div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b> Добавил краткое описание.</div>

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# Проверим наличие пользователей в двух группах одновременно.

# %%
grA = orders[orders['group']=='A']['user_id']
grB = orders[orders['group']=='B']['user_id']

duplicated = pd.concat([grB[grB.isin(grA)], grA[grA.isin(grB)]], axis=0)
print('Период проведения теста:', orders['date'].dt.date.min(), orders['date'].dt.date.max())
print('Исходное количество пользователей в группе А:', grA.agg('nunique'))
print('Исходное количество пользователей в группе B:', grB.agg('nunique'))
print('Количество дубликатов:', len(duplicated))
# Out:
# Период проведения теста: 2019-08-01 2019-08-31
# Исходное количество пользователей в группе А: 503
# Исходное количество пользователей в группе B: 586
# Количество дубликатов: 181

# %% [markdown]
# Обнаружена 181 строка с пользователями, которые оказались одновременно в двух группах. Исключим их из таблицы `orders`:

# %%
orders = orders.drop(duplicated.index).reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Отлично, что не забыл проверить пересекающуюся аудиторию :)
# </div>
# <div class="alert alert-block alert-warning"> ⚠️ <b>Комментарий ревьюера:</b> Было бы здорово ещё посмотреть сколько изначально было пользователей в каждой из групп. Также можно ещё оценить периоды в исходных данных, совпадают ли они (как до, так и после удаления)</div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b> Посмотрел изначальное количество пользователей в группах и оценил период проведения теста.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning"> ⚠️ <b>Комментарий ревьюера 2:</b> Всё здорово. Прошу прощения, не обратил сразу внимание на это. При таком подсчёте len(grA) не совсем точное кол-во ползователей, т.к. они могут повторяться, то корректнее считать через nunique. Или же при составлении grA или grB добавить unique(), чтобы отобрать именно уникальных </div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента 2:</b> Поправил расчет уникальных пользователей.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера 3:</b> Всё супер :)
# </div>

# %% [markdown]
# Проверим количество пользователей в каждой группе после удаления дубликатов:

# %%
print('Период проведения теста:', orders['date'].dt.date.min(), orders['date'].dt.date.max())
print('Количество пользователей в группе А:', orders[orders['group']=='A']['user_id'].agg('nunique'))
print('Количество пользователей в группе B:', orders[orders['group']=='B']['user_id'].agg('nunique'))
# Out:
# Период проведения теста: 2019-08-01 2019-08-31
# Количество пользователей в группе А: 445
# Количество пользователей в группе B: 528

# %% [markdown]
# Удаленные дубликаты не повлияли на период проведения теста.
# Заметим, что количество пользователей в группе В больше, чем в группе А. Удалять пользователей для выравнивая групп не будем, однако, следует учесть, что разница в количестве пользователей может повлиять на результаты анализа.

# %% [markdown]
# ### Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %%
# создаем массив уникальных пар значений дат и групп теста
datesGroups = orders[['date','group']].drop_duplicates() 

# получаем агрегированные кумулятивные по дням данные о заказах 
ordersAggregated = datesGroups.apply( \
                        lambda x: orders[np.logical_and(orders['date'] <= x['date'], \
                        orders['group'] == x['group'])] \
                        .agg({ \
                              'date' : 'max', \
                              'group' : 'max', \
                              'order_id' : 'nunique', \
                              'user_id' : 'nunique', \
                              'revenue' : 'sum'}), \
                        axis=1).sort_values(by=['date','group']) 

# получаем агрегированные кумулятивные по дням данные о посетителях интернет-магазина 
visitorsAggregated = datesGroups.apply( \
                        lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], \
                        visitors['group'] == x['group'])] \
                        .agg({ \
                              'date' : 'max', \
                              'group' : 'max', \
                              'visitors' : 'sum'}), \
                        axis=1).sort_values(by=['date','group'])

# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия
cumulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cumulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А
cumulativeRevenueA = cumulativeData[cumulativeData['group']=='A'][['date','revenue', 'orders']]

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B
cumulativeRevenueB = cumulativeData[cumulativeData['group']=='B'][['date','revenue', 'orders']]

# Строим график выручки группы А
plt.figure(figsize=(15, 5))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue'], label='A')

# Строим график выручки группы B
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue'], label='B')
plt.xticks(rotation=0)
plt.ylabel('выручка')
plt.title('Кумулятивная выручка по группам')
plt.legend() 
plt.grid(True)

# %% [markdown]
# В середине теста сегмент B вырвался вперёд и продолжал лидировать весь остаток теста. Похоже, что аномально большие заказы влияют на результаты.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Всё верно, резкий скачок может сигнализировать о всплесках числа заказов, либо о появлении очень дорогих заказов в выборке :)
# </div>

# %% [markdown]
# ### Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %%
# строим график кумулятивного среднего чека по группам
plt.figure(figsize=(15, 5))
plt.plot(cumulativeRevenueA['date'], cumulativeRevenueA['revenue']/cumulativeRevenueA['orders'], label='A')
plt.plot(cumulativeRevenueB['date'], cumulativeRevenueB['revenue']/cumulativeRevenueB['orders'], label='B')
plt.xticks(rotation=0)
plt.ylabel('средний чек')
plt.title('Кумулятивный средний чек по группам')
plt.legend() 
plt.grid(True)

# %% [markdown]
# Кумулятивное значение среднего чека сначала колебалось. Затем для группы А стабилизировалось. Для группы В наблюдается аномальный скачок и затем тенденция к устойчиовму постепенному снижению. Скорее всего, принимать решение по этой метрике рано. Или требуется дополнительный анализ выбросов, которые искажают результаты.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Верный вывод :)
# </div>

# %% [markdown]
# ### Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %%
# собираем данные в одном датафрейме
mergedCumulativeRevenue = cumulativeRevenueA.merge(
    cumulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B']
)

# cтроим отношение средних чеков
plt.figure(figsize=(15, 5))
plt.plot(
    mergedCumulativeRevenue['date'], 
    (mergedCumulativeRevenue['revenueB']/mergedCumulativeRevenue['ordersB'])/
    (mergedCumulativeRevenue['revenueA']/mergedCumulativeRevenue['ordersA'])-1
)

# добавляем ось X
plt.axhline(y=0, color='black', linestyle='--') 
plt.xticks(rotation=0)
plt.ylabel('относительный средний чек')
plt.title('Относительное изменения кумулятивного среднего чека группы B к группе A')
plt.grid(True)

# %% [markdown]
# Результаты теста значительно и резко менялись в несколько дат. Видимо, именно тогда были совершены аномальные заказы.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Действительно, выбросы влияют на относительное изменение :)
# </div>

# %% [markdown]
# ### Постройте график кумулятивной конверсии по группам. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %%
# считаем кумулятивную конверсию
cumulativeData['conversion'] = cumulativeData['orders']/cumulativeData['visitors']

# отделяем данные по группе A
cumulativeDataA = cumulativeData[cumulativeData['group']=='A']

# отделяем данные по группе B
cumulativeDataB = cumulativeData[cumulativeData['group']=='B']

# строим графики
plt.figure(figsize=(15, 5))
plt.plot(cumulativeDataA['date'], cumulativeDataA['conversion'], label='A')
plt.plot(cumulativeDataB['date'], cumulativeDataB['conversion'], label='B')
plt.legend()

# задаем масштаб осей
plt.ylim(0, 0.04)
plt.xticks(rotation=0)
plt.ylabel('конверсия')
plt.title('Кумулятивная конверсия по группам')
plt.grid(True)

# %% [markdown]
# В начале сегмент А имел большую конверсию, но постепенно сегмент В выровнялся и зафисикровался около одного значения, больше сегмента А.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Конверсия В лучше конверсии А  :)
# </div>

# %% [markdown]
# ### Постройте график относительного изменения кумулятивной конверсии группы B к группе A. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %%
# собираем данные в одном датафрейме
mergedCumulativeConversions = cumulativeDataA[['date','conversion']] \
                        .merge(cumulativeDataB[['date','conversion']], \
                        left_on='date', right_on='date', how='left', suffixes=['A', 'B'])

# cтроим отношение конверсий
plt.figure(figsize=(15, 5))
plt.plot(
    mergedCumulativeConversions['date'], 
    mergedCumulativeConversions['conversionB']/mergedCumulativeConversions['conversionA']-1, 
    label="Относительный прирост конверсии группы B относительно группы A"
)
plt.ylabel('относительный прирост\n кумулятивной конверсии')
plt.title('График относительного изменения кумулятивной конверсии группы B к группе A')
plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.15, color='grey', linestyle='--')
plt.xticks(rotation=0)
plt.yticks(np.arange(-0.5, 0.5, 0.1))
plt.grid(True)

# %% [markdown]
# Почти с самого начала группа В лидирует по конверсии: становится лучше и лучше, либо колеблется около прироста 15% относительно группы А.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Здесь также можно установить ahline на уровне 0.1, т.к. ниже этой отметки график не опускается большую часть периода :)
# </div>

# %% [markdown]
# ### Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %%
# подсчитаем количество заказов по пользователям
ordersByUsers = (
    orders.groupby('user_id', as_index=False)
    .agg({'order_id': 'nunique'})
)

ordersByUsers.columns = ['user_id', 'orders']

# построим точечный график количества заказов по пользователям.
plt.figure(figsize=(15, 5))
plt.scatter(ordersByUsers.index, ordersByUsers['orders']) 
plt.grid(True)
plt.ylabel('количество заказов')
plt.xlabel('порядковый номер пользователя')
plt.title('Количество заказов по пользователям');

# %% [markdown]
# Большинство покупателей заказывали только один раз. Остальные пользователи делали 2 или 3 заказа.

# %% [markdown]
# ### Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %%
# посчитаем 95-й и 99-й перцентили количества заказов на пользователя
print(np.percentile(ordersByUsers['orders'], [95, 99]))
# Out:
# [1. 2.]

# %% [markdown]
# Не более 5% пользователей оформляли более одного заказа. И 1% пользователей заказывали более двух раз.
# Разумно выбрать один заказ на одного пользователя за нижнюю границу числа заказов, и отсеять аномальных пользователей по ней.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Всё верно. Но, на мой взгляд, лучше взять всё е 99 перцентиль за границу аномальных заказов :)
# </div>

# %% [markdown]
# ### Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %%
# построим точечный график стоимостей заказов
plt.figure(figsize=(15, 5))
plt.scatter(orders.index, orders['revenue']) 
plt.grid(True)
plt.ylabel('стоимость заказов')
plt.xlabel('порядковый номер пользователя')
plt.title('Стоимость заказов по пользователям');

# %% [markdown]
#  Есть немного дорогих заказов. По графику можно выбрать границу аномальных заказов выше 100 000 рублей. Уточним границу в следующем разделе.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Из графика видно только 2 явных выброса. Для более точного определения границы можно построить график без этих заказов :)
# </div>

# %% [markdown]
# ### Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %%
# посчитаем 95-й и 99-й перцентили стоимости заказов
print(np.percentile(orders['revenue'], [95, 99]))
# Out:
# [26785. 53904.]

# %% [markdown]
# Не более 5% заказов дороже 26785 рублей и не более 1% дороже 53904 рублей.
# Примем за аномальных пользователей тех, кто совершил заказ дороже 53904 рублей.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Хорошее решение взять в качестве границы 99 перцентиль :)
# </div>

# %% [markdown]
# ### Посчитайте статистическую значимость различий в конверсии между группами по «сырым» данным. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# Введем нулевую и альтернативные гипотезы:
# - H0:Различий в конверсии между группами нет.
# - H1:Различия в конверсии между группами есть.
#
# Уровень значимости:  𝛼=0.05
# Рассчитаем p-value. Если p-value будет меньше выбранного уровня значимости ( 𝛼=0.05 ), то будут основания отвергнуть нулевую гипотезу в пользу альтернативной. Иначе сделаем вывод, что данные не позволили нам отвергнуть нулевую гипотезу.

# %%
# количество пользователей в выбранную дату в группе A
visitorsADaily = visitors[visitors['group'] == 'A'][['date', 'visitors']]
visitorsADaily.columns = ['date', 'visitorsPerDateA']

# количество пользователей в выбранную дату в группе B
visitorsBDaily = visitors[visitors['group'] == 'B'][['date', 'visitors']]
visitorsBDaily.columns = ['date', 'visitorsPerDateB']

# %%
# создадим переменные для пользователей, которые заказывали хотя бы 1 раз
ordersByUsersA = (
    orders[orders['group'] == 'A']
    .groupby('user_id', as_index=False)
    .agg({'order_id': 'nunique'})
)
ordersByUsersA.columns = ['user_id', 'orders']

ordersByUsersB = (
    orders[orders['group'] == 'B']
    .groupby('user_id', as_index=False)
    .agg({'order_id': 'nunique'})
)
ordersByUsersB.columns = ['user_id', 'orders']

# переменные sampleA и sampleB, в которых пользователям из разных групп будет соответствовать количество заказов
sampleA = pd.concat(
    [
        ordersByUsersA['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitorsADaily['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleB = pd.concat(
    [
        ordersByUsersB['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitorsBDaily['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

print("p-значение: {0:.3f}".format(stats.mannwhitneyu(sampleA, sampleB)[1]))
print("Отношение В к А: {0:.3f}".format(sampleB.mean() / sampleA.mean() - 1))
# Out:
# p-значение: 0.011
# Отношение В к А: 0.160

# %% [markdown]
# P-значение меньше 0.05, поэтому нулевую гипотезу отвергаем. Анализ «сырых данных» сообщает, что в среднем количестве заказов между группами есть статистически значимые различия. Относительный прирост среднего группы B к конверсии группы A равен 16%. Осталось сравнить средние чеки по «сырым данным», а затем обе метрики ещё раз после удаления выбросов.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Верный вывод :)
# </div>
# <div class="alert alert-block alert-danger"> ❌ <b>Комментарий ревьюера:</b> Но не хватает постановки гипотез (касается и расчётов ниже)
# </div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b> Добавил постановку гипотез.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера 2:</b> Формулировка корректная :)
# </div>

# %% [markdown]
# ### Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# Введем нулевую и альтернативные гипотезы:
#
# - H0:Различий в среднем чеке между группами нет
# - H1:Различия в среднем чеке между группами есть.
#
# Уровень значимости:  𝛼=0.05
# Рассчитаем p-value. Если p-value будет меньше выбранного уровня значимости ( 𝛼=0.05 ), то будут основания отвергнуть нулевую гипотезу в пользу альтернативной. Иначе сделаем вывод, что данные не позволили нам отвергнуть нулевую гипотезу.

# %%
print('p-значение: {0:.3f}'.format(
    stats.mannwhitneyu(orders[orders['group'] == 'A']['revenue'], 
                       orders[orders['group'] == 'B']['revenue'])[1])
     )
print('Отношение В к А: {0:.3f}'.format(
    orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1)
     )
# Out:
# p-значение: 0.829
# Отношение В к А: 0.287

# %% [markdown]
# p-значение больше 0.05 - статистически значимых отличий в среднем чеке между группами нет. При этом относительное различие в среднем чеке равно 28.7%

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Действительно по среднему чеку отличий нет, несмотря на отн. разницу в 28.7%:)
# </div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b> Добавил постановку гипотез.</div>

# %% [markdown]
# ### Посчитайте статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# Введем нулевую и альтернативные гипотезы:
# - H0:Различий в конверсии между группами нет.
# - H1:Различия в конверсии между группами есть.
#
# Уровень значимости:  𝛼=0.05
# Рассчитаем p-value. Если p-value будет меньше выбранного уровня значимости ( 𝛼=0.05 ), то будут основания отвергнуть нулевую гипотезу в пользу альтернативной. Иначе сделаем вывод, что данные не позволили нам отвергнуть нулевую гипотезу.

# %%
# узнаем, сколько всего аномальных пользователей
usersWithManyOrders = pd.concat(
    [
        ordersByUsersA[ordersByUsersA['orders'] > 1]['user_id'],
        ordersByUsersB[ordersByUsersB['orders'] > 1]['user_id'],
    ],
    axis=0,
)
usersWithExpensiveOrders = orders[orders['revenue'] > 53904]['user_id']
abnormalUsers = (
    pd.concat([usersWithManyOrders, usersWithExpensiveOrders], axis=0)
    .drop_duplicates()
    .sort_values()
)
abnormalUsers
# Out:
# 937      148427295
# 33       249864742
# 36       366673373
# 51       406208401
# 67       522292794
# 58       611059232
# 64       678354126
# 72       759473111
# 811      887908475
# 632      888512513
# 939     1164614297
# 971     1307669133
# 176     1404560065
# 171     1617417821
# 208     1637811943
# 180     1772171838
# 365     1920142716
# 250     1985475298
# 256     2025197455
# 265     2096506107
# 1015    2108080724
# 211     2108163459
# 227     2232111114
# 239     2306096143
# 296     2366521417
# 303     2397843657
# 279     2706377257
# 282     2733145037
# 347     2742574263
# 286     2744017357
# 302     2892265953
# 310     2988190573
# 388     3077396270
# 418     3332057097
# 421     3362039251
# 425     3379260072
# 374     3469608676
# 409     3908431265
# 486     3935952912
# 489     3941503500
# 416     3967698036
# 802     4003628586
# 430     4109358064
# 631     4133034833
# 507     4134830387
# Name: user_id, dtype: int64

# %%
# отфильтруем аномальных пользователей
sampleAFiltered = pd.concat(
    [
        ordersByUsersA[
            np.logical_not(ordersByUsersA['user_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitorsADaily['visitorsPerDateA'].sum() - len(ordersByUsersA['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
)

sampleBFiltered = pd.concat(
    [
        ordersByUsersB[
            np.logical_not(ordersByUsersB['user_id'].isin(abnormalUsers))
        ]['orders'],
        pd.Series(
            0,
            index=np.arange(
                visitorsBDaily['visitorsPerDateB'].sum() - len(ordersByUsersB['orders'])
            ),
            name='orders',
        ),
    ],
    axis=0,
) 

print('p-значение: {0:.3f}'.format(stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)[1]))
print('Отношение В к А: {0:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))
# Out:
# p-значение: 0.008
# Отношение В к А: 0.188

# %% [markdown]
# Результаты конверсии пользователей по очищенным данным практически не изменились. Как и в случае с сырыми данными статистическая значимость достигнута. Относительный прирост конверсии группы B к конверсии группы A равен 18.8%

# %% [markdown]
# <div class="alert alert-block alert-warning"> ⚠️ <b>Комментарий ревьюера:</b> Точно ли здесь рассматривалось среднее кол-во заказов?</div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b> Поправил вывод и добавил постановку гипотез.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера 2:</b> Да, здевь проверялась конверсия :)
# </div>

# %% [markdown]
# ### Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# Введем нулевую и альтернативные гипотезы:
#
# - H0:Различий в среднем чеке между группами нет
# - H1:Различия в среднем чеке между группами есть.
#
# Уровень значимости:  𝛼=0.05
# Рассчитаем p-value. Если p-value будет меньше выбранного уровня значимости ( 𝛼=0.05 ), то будут основания отвергнуть нулевую гипотезу в пользу альтернативной. Иначе сделаем вывод, что данные не позволили нам отвергнуть нулевую гипотезу.

# %%
print(
    'p-значение: {0:.3f}'.format(
        stats.mannwhitneyu(
            orders[
                np.logical_and(
                    orders['group'] == 'A',
                    np.logical_not(orders['user_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
            orders[
                np.logical_and(
                    orders['group'] == 'B',
                    np.logical_not(orders['user_id'].isin(abnormalUsers)),
                )
            ]['revenue'],
        )[1]
    )
)

print(
    "Отношение В к А: {0:.3f}".format(
        orders[
            np.logical_and(
                orders['group'] == 'B',
                np.logical_not(orders['user_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        / orders[
            np.logical_and(
                orders['group'] == 'A',
                np.logical_not(orders['user_id'].isin(abnormalUsers)),
            )
        ]['revenue'].mean()
        - 1
    )
)
# Out:
# p-значение: 0.969
# Отношение В к А: 0.002

# %% [markdown]
# P-value увеличился и статистически значимых отличий в среднем чеке между группами нет, но и разница между сегментами сократилась и теперь равна менее одного процента.

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b> Добавил постановку гипотез.</div>

# %% [markdown]
# ### Примите решение по результатам теста и объясните его.

# %% [markdown]
# [Вернуться к оглавлению](#Оглавление)

# %% [markdown]
# Результаты анализа А/В теста:
# - Есть статистически значимое различие по конверсии между группами как по сырым данным, так и после фильтрации аномалий.
# - Нет статистически значимого различия по среднему чеку между группами как по сырым данным, так и после фильтрации аномалий.
# - График различия конверсии между группами показывает, что результаты группы B лучше группы A: имеют тенденцию к росту, либо зафиксировались около среднего значения.
# - График различия среднего чека колеблется. После аномального скачка наблюдается тендеция к снижению показателя среднего чека группы В относительно группы А.
#
# Исходя из обнаруженных фактов, тест следует остановить и признать его успешным. Конверсия группы В стабильно показывает результат выше, чем конверсия группы А.

# %% [markdown]
# <div class="alert alert-block alert-success">✅ <b>Комментарий ревьюера:</b> Хороший итоговый вывод :)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger"> <b>Итоги ревью:</b> Отличный проект. Проделана качественная работа. Отдельно отмечу визуализацию. Но, к сожалению, есть несколько замечаний, требующие корректировок и уточнений. Желаю успехов и жду работу на повторное ревью :)
# </div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента:</b>
#
# Устранил замечания:
#
# - Добавил описание разделов в разделах 3 и 4.
# - Добавил описание отличия методов ICE и RICE.
# - Добавил изначальное количество пользователей в группах и оценил период проведения теста.
# - Добавил постановку гипотез.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning"> <b>Итоги ревью 2:</b> Все критические замечания исправлены корректно. Оставил новый жёлтый комментраий (не заметил при первой проверке небольшую неточность). После этого уточнения проект  будет принят. Желаю успехов :)
# </div>

# %% [markdown]
# <div class="alert alert-info"><b>Комментарий студента 2:</b> Поправил расчет уникальных пользователей.</div>

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Итоги ревью 3:</b> Проект принят. Проделана отличная работа.  Желаю успехов в будущих исследованиях  :)
# </div>
