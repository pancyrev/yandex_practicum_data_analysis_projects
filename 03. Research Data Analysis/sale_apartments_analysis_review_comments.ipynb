# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Отлично, Евгений! Ты исправил все, даже самые незначительные недостатки и теперь твой проект конечно же принят. Однако, я всё же отправлю проект тебе ещё раз, вдруг ты захочешь в него добавить что-то еще или просто взглянуть на него. Когда решишь, что ты готов закончить проект, просто отправь мне его и я его сразу приму.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Ура! Дмитрий, спасибо!</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 3.0 ✔️:</b> Проект принят. Спасибо за работу!)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Привет!</b>
#
# Меня зовут Михаленко Дмитрий, и я буду проверять твой проект. Предлагаю общаться на «ты» :) Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их**. Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой начальник будет поступать так же, а я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Так выделены небольшие замечания. Я надеюсь, что их ты тоже учтешь - твой проект от этого станет только лучше. Но настаивать на их отработке не буду.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом.** Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#
# Дмитрий, привет! Спасибо за проверку и ценные комментарии.
# Устранил замечание и добавил в раздел 4.3 исследование аномальных значений:
# * Аномальные значения жилой площади
# * Проверка значений, где сумма жилой площади и кухни больше общей площади
# * Аномальные цены квартир
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Ты очень хорошо поработал над комментариями

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Предварительная-проверка-дубликатов" data-toc-modified-id="Предварительная-проверка-дубликатов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Предварительная проверка дубликатов</a></span></li><li><span><a href="#Проверка-пропусков" data-toc-modified-id="Проверка-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка пропусков</a></span></li><li><span><a href="#Исправление-типов-данных" data-toc-modified-id="Исправление-типов-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исправление типов данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Расчет-цены-квадратного-метра" data-toc-modified-id="Расчет-цены-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Расчет цены квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры:-первый,-последний,-другой." data-toc-modified-id="Этаж-квартиры:-первый,-последний,-другой.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Этаж квартиры: первый, последний, другой.</a></span></li><li><span><a href="#Cоотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей." data-toc-modified-id="Cоотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Cоотношение жилой и общей площади, а также отношение площади кухни к общей.</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра" data-toc-modified-id="Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра</a></span></li><li><span><a href="#Изучите-время-продажи-квартиры" data-toc-modified-id="Изучите-время-продажи-квартиры-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите время продажи квартиры</a></span></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили." data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?" data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры?</a></span></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах.</a></span></li><li><span><a href="#Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге.-Ваша-задача-—-выяснить,-какая-область-входит-в-центр." data-toc-modified-id="Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге.-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге. Ваша задача — выяснить, какая область входит в центр.</a></span></li><li><span><a href="#Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию" data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделите сегмент квартир в центре. Проанализируйте эту территорию</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Объёмная и творческая аналитическая задача, тем интереснее будет с ней справиться! </div>

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Заметь, ячейки в тетрадке исполняются, начиная не с единицы. Перед отправкой проекта на проверку его стоит перезапускать через Kernel - Restart & Runall </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
# Исследуем названия столбцов:
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Описание полей данных:
# * `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# * `balcony` — число балконов
# * `ceiling_height` — высота потолков (м)
# * `cityCenters_nearest` — расстояние до центра города (м)
# * `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# * `first_day_exposition` — дата публикации
# * `floor` — этаж
# * `floors_total` — всего этажей в доме
# * `is_apartment` — апартаменты (булев тип)
# * `kitchen_area` — площадь кухни в квадратных метрах (м²)
# * `last_price` — цена на момент снятия с публикации
# * `living_area` — жилая площадь в квадратных метрах (м²)
# * `locality_name` — название населённого пункта
# * `open_plan` — свободная планировка (булев тип)
# * `parks_around3000` — число парков в радиусе 3 км
# * `parks_nearest` — расстояние до ближайшего парка (м)
# * `ponds_around3000` — число водоёмов в радиусе 3 км
# * `ponds_nearest` — расстояние до ближайшего водоёма (м)
# * `rooms` — число комнат
# * `studio` — квартира-студия (булев тип)
# * `total_area` — площадь квартиры в квадратных метрах (м²)
# * `total_images` — число фотографий квартиры в объявлении

# %%
# Ислледуем df по типу данных и наличие пропусков
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
print('Всего строк в df', len(df))
print('Пропуски в стобцах: \n', df.isna().sum())
# Out:
# Всего строк в df 23699
# Пропуски в стобцах:
#  total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Подсчет доли пропусков в %:

# %%
round(df.isna().sum() * 100 / len(df), 2)
# Out:
# total_images             0.00
# last_price               0.00
# total_area               0.00
# first_day_exposition     0.00
# rooms                    0.00
# ceiling_height          38.80
# floors_total             0.36
# living_area              8.03
# floor                    0.00
# is_apartment            88.29
# studio                   0.00
# open_plan                0.00
# kitchen_area             9.61
# balcony                 48.61
# locality_name            0.21
# airports_nearest        23.38
# cityCenters_nearest     23.29
# parks_around3000        23.28
# parks_nearest           65.91
# ponds_around3000        23.28
# ponds_nearest           61.56
# days_exposition         13.42
# dtype: float64

# %% [markdown]
# ### Вывод

# %% [markdown]
# Данные представлены в таблице из 22 стобцов и 23699 строк.
# Названия столбцов составлены стилистически верно. Переименовывать не требуется.
# Таблица содержит пропуски. Необходимо оценить причины появления пропусков и как они влияют на анализ.
# Также требуется исправить типы данных в столбцах `first_day_exposition`, `floors_total`, `is_apartment`, `parks_around3000`, `ponds_around3000`, `days_exposition`.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Хорошее начало и первый промежуточный вывод, так держать. </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Предварительная проверка дубликатов

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# В исходной таблице дубликаты не найдены.

# %% [markdown]
# ### Проверка пропусков

# %% [markdown]
# 0. Таблица `df` содержит пропуски в следующих столбцах (%):

# %%
round(df.isna().sum() * 100 / len(df), 2).sort_values()
# Out:
# total_images             0.00
# open_plan                0.00
# floor                    0.00
# rooms                    0.00
# studio                   0.00
# total_area               0.00
# last_price               0.00
# first_day_exposition     0.00
# locality_name            0.21
# floors_total             0.36
# living_area              8.03
# kitchen_area             9.61
# days_exposition         13.42
# ponds_around3000        23.28
# parks_around3000        23.28
# cityCenters_nearest     23.29
# airports_nearest        23.38
# ceiling_height          38.80
# balcony                 48.61
# ponds_nearest           61.56
# parks_nearest           65.91
# is_apartment            88.29
# dtype: float64

# %% [markdown]
# 1. Исследуем столбец с наименованиями населенных пунктов `locality_name`.

# %%
df['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# В списке присутствуют дубликаты названий населенных пунктов. Например: 'посёлок Мурино', 'поселок Мурино' и 'Мурино'. Часто встречаются дубликаты `посёлок` и `поселок`.
#
# Во всех названиях населенных пунктов проведем замену `поселок` на `посёлок`.
# Также создадим отдельный столбец `city_name`, который будет содержать только названия населенных пунктов.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Молодец, что поработал с неявными дубликатами

# %%
# Заменим NaN на None
df['locality_name'] = df['locality_name'].fillna(value='None')

# Заменим посел на посёл
df['locality_name'] = df['locality_name'].str.replace('посел', 'посёл')

# Функция, которая отделяет тип населенного пункта от названия 
def city_name(val):
    if ('посёлок городского типа' in val):
        return val.replace('посёлок городского типа ', '')
    if ('городской посёлок' in val):
        return val.replace('городской посёлок ', '')
    if ('коттеджный посёлок' in val):
        return val.replace('коттеджный посёлок ', '')    
    if ('посёлок' in val):
        return val.replace('посёлок ', '')  
    if ('деревня' in val):
        return val.replace('деревня ', '')  
    if ('садовое товарищество' in val):
        return val.replace('садовое товарищество ', '')          
    if ('село' in val):
        return val.replace('село ', '')  
    if ('садоводческое некоммерческое товарищество' in val):
        return val.replace('садоводческое некоммерческое товарищество ', '')    
    return val

# Создадим столбец city_name с названием городов
df['city_name'] = df['locality_name'].apply(city_name)
df['city_name'].value_counts().head(10)
# Out:
# Санкт-Петербург    15721
# Мурино               590
# Кудрово              472
# Шушары               440
# Всеволожск           398
# Пушкин               369
# Колпино              338
# Парголово            327
# Гатчина              307
# Выборг               237
# Name: city_name, dtype: int64

# %%
print('Количество неизвестных населенных пунктов', len(df[df['locality_name']=='None']))
# Out:
# Количество неизвестных населенных пунктов 49

# %% [markdown]
# Всего в таблице 49 населенных пункта без названия. Т.к. сумма объявлений из населенных пунктов не попадает в список населенных пунктов с наибольшим количеством объявлений, то оставим пропуски со значением `None` в столбце `locality_name`.
#
# Восстановить названия населенных пунктов по имеющимся данным невозможно. Причину отсутствия данных установить невозможно. Необходимо сообщить ответственному отделу об отсутствии информации по населенным пунктам.

# %% [markdown]
# 2. Столбец с количеством этажей `floors_total` имеет пропуски. Величина пропусков составлят менее 1%.
#
# Восстановить пропуски по количеству этажей по имеющимся данным невозможно. Причина отстутствия данных: либо пользователь не заполнил данные, либо ошибка при выгрузке данных. Необходимо сообщить ответственному отделу об отсутствии информации по числу этажей в домах, в которых продаются квартиры.

# %%
# Заменинм пропуски в количестве этажей в здании на 0
df['floors_total'] = df['floors_total'].fillna(0)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Согласен с таким решением

# %% [markdown]
# 3. Заполним пропуски в столбце `living_area` - жилая площадь. Пропуски составляют 8% данных.
#
# Проверим корреляцию между общей площадью квартиры и жилой площадью.

# %%
# Рассчитаем коэффицент корреляции
print(df['living_area'].corr(df['total_area']))

# Построим диаграмму рассеяния
df.plot(x='living_area', y='total_area', kind='scatter');
# Out:
# 0.9395373338721493

# %% [markdown]
# Коэффициент корреляции высокий, равен 0,94. Значит есть прямая связь между общей и жилой площадью.
#
# Чтобы заполнить пропуски, разобьем общую площадь на группы: 0-25 кв.м, 25-50 кв.м, 50-75 кв.м, 75-100 кв.м, 100-150 кв., 150-200 кв.м. Для каждой группы вычислим отношение медиан общей и жилой площади. Для каждого пропуска в жилой площади разделим общую площадь на найденный коэффициент `area_ratio`.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Найти тут коэффициент для заполнения это хорошее решение

# %%
# Разобъем общую площадь по группам
cut_labels = ['25', '50', '75', '100', '150', '200']
cut_bins = [0, 25, 50, 75, 100, 150, 1000]
df['area_group'] = pd.cut(df['total_area'],
                             bins=cut_bins,
                             labels=cut_labels)

# Определим отношение медиан общей площади к жилой для каждой группы
area_ratio = df.groupby('area_group')['total_area'].median() / df.groupby('area_group')['living_area'].median()

# Создадим датафрейм с коэффициентом площадей
area_ratio = pd.DataFrame(area_ratio)

# Переименуем колонку в датафрейме
area_ratio.columns = ['area_ratio']

# Объединим общий датафрейм с датафреймом area_ratio
df = df.join(area_ratio, on='area_group')

# Рассчитаем пропуски в жилой площади через коэффицент площадей
df['living_area'] = df['living_area'].fillna(df['total_area'] / df['area_ratio'])

# %% [markdown]
# Были заполнены пропуски в столбце с данными о жилой площади. Пропуски могли проявиться из-за того, что пользователи не внесли данную информацию в объявление. Однако по имеющимся данным о общей плоащди жилья удалось восстановить пропущенные значения.

# %% [markdown]
# 4. Заполним пропуски в столбце `kitchen_area`. Пропуски составляют 9.6% данных.
#
# Проверим корреляцию между общей площадью квартиры и жилой площадью.

# %%
# Рассчитаем коэффицент корреляции
print(df['kitchen_area'].corr(df['total_area']))

# Построим диаграмму рассеяния
df.plot(x='kitchen_area', y='total_area', kind='scatter');
# Out:
# 0.6091211711198318

# %% [markdown]
# Корреляция не очень. Построим зависимость медианных значений площади кухни и общей площади.

# %%
df.groupby('area_group')[['total_area', 'kitchen_area']].median().plot(x='kitchen_area', y='total_area');

# %% [markdown]
# На построенном графике лучше прослеживается зависимость между общей площадью и площадью кухни.
# Чтобы заполнить пропуски, воспользуемся ранее проделанной разбивкой на группы общей площади. Для каждой группы вычислим отношение медиан общей площадью и кухней. Для каждого пропуска в площади кухни разделим общую площадь на найденный коэффициент `kitchen_ratio`.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Молодец, все верно!

# %%
# Воспользуемся группами area_group найденными раньше
# Определим отношение медиан общей площади к площади кухни для каждой группы
kitchen_ratio = (
    df.groupby('area_group')['total_area'].median() / 
    df.groupby('area_group')['kitchen_area'].median()
)

# Создадим датафрейм с коэффициентом площадей
kitchen_ratio = pd.DataFrame(kitchen_ratio)

# Переименуем колонку в датафрейме
kitchen_ratio.columns = ['kitchen_ratio']

# Объединим общий датафрейм с датафреймом kitchen_ratio
df = df.join(kitchen_ratio, on='area_group')

# Заполним пропуски в площади кухни через коэффицент площадей
df['kitchen_area'] = df['kitchen_area'].fillna(df['total_area'] / df['kitchen_ratio'])

# %% [markdown]
# Были заполнены пропуски в столбце с данными о площади кухни. Пропуски, возможно, были допущены из-за того, что пользователи не указали значения при оформлении объявления. Однако имеющиеся данные по общей площади квартир, позволили заполнить пропуски.

# %% [markdown]
# 5. Столбец с количеством дней до продажи `days_exposition` имеет пропущенные значения. Количесвто пропусков 13,4%. Скорей всего это означает, что объявление о продаже до сих пор действительно.
# Заменим пропуски на разницу между датой загрузки объявления и датой выгрузки базы. <a id='date'></a>

# %%
# Изменим формат столбца с датой на datetime
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%d')

# Вычислим количество дней от момента публикации до выгрузки базы
df['delta_day'] = df['first_day_exposition'].max() - df['first_day_exposition']

# Заполним пропуски в days_exposition из столбца delta_day
df['days_exposition'] = df['days_exposition'].fillna(df['delta_day'].dt.days)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Отлично

# %% [markdown]
# Пропуски в столбце с количеством дней до продажи возникли из-за того, что на момент выгрузки базы объявления о продаже были актуальны. Пропуски были заполнены значениями равными разнице дней между публикацией объявления и выгрузкой базы.

# %% [markdown]
# 6. Исследуем пропуски в данных о водоемах `ponds_around3000` и `ponds_nearest`. Пропуски равны 23,3% и 61,6%

# %%
#Количество пропусков и количество строк с `0` в столбце ponds_around3000
print(
    df[df['ponds_around3000']==0]['ponds_around3000'].count() + 
    df['ponds_around3000'].isna().sum()
)

#Количество пропусков в столбце ponds_nearest
print(df['ponds_nearest'].isna().sum())
# Out:
# 14589
# 14589

# %% [markdown]
# Заметим, что сумма нулевых и пропущенных значений в столбце `ponds_around3000` равна количеству пропущенных значений в столбце `ponds_nearest`.
#
# Заменим пропуски в столбце `ponds_around3000` на `0`. Пропуски в столбце с расстояниями до ближайшего водоема оставим как есть.

# %%
df['ponds_around3000'] = df['ponds_around3000'].fillna(0)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Все логично

# %% [markdown]
# Проверим предположение, что значения `NaN` столбца `ponds_nearest` и `0` столбца `ponds_around3000` находятся в одних и тех же строках:

# %%
(
    df.loc
    [
        (df['ponds_around3000']==0) & (df['ponds_nearest'].isna())
    ]
    [
        ['ponds_around3000', 'ponds_nearest']
    ]
    .sum()
)
# Out:
# ponds_around3000    0.0
# ponds_nearest       0.0
# dtype: float64

# %% [markdown]
# Пропуски в столбце с информацией о количестве водоемов в окрестности 3000м были заполнены нулями.
# Пропуски в столбце с информацией о близлежащих прудах оставлены как есть. Пропуски означают, что пруды отсутствуют в окрестности как минимум 3000м.

# %% [markdown]
# 7. Исследуем пропуски в данных о парках `parks_around3000` и `parks_nearest`. Пропуски равны 23,3% и 65,9% соответственно.

# %%
#Количество пропусков и количество строк с `0` в столбце parks_around3000
print(
    df[df['parks_around3000']==0]['parks_around3000'].count() 
    + df['parks_around3000'].isna().sum()
)

#Количество пропусков в столбце parks_nearest
print(df['parks_nearest'].isna().sum())
# Out:
# 15624
# 15620

# %% [markdown]
# Заменим пропуски в столбце `parks_around3000` на `0`. Пропуски в столбце с расстояниями до ближайшего парка оставим как есть.

# %%
df['parks_around3000'] = df['parks_around3000'].fillna(0)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Здесь также все хорошо

# %% [markdown]
# Число парков в столбце `parks_nearest` на четыре больше, чем нулевых записей в столбце `parks_around3000`.
# Проверим какие четыре парка находятся на расстоянии больше 3000м.

# %%
df[(df['parks_around3000']==0) & (df['parks_nearest'].notna())]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1590              3   7500000.0        70.0           2017-07-11      2
# 10959             9   3000000.0        31.1           2017-03-21      1
# 19208            17  14950000.0       187.0           2017-10-12      5
# 19430             9   3900000.0        30.5           2018-02-22      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 1590              NaN          18.0         37.0     13          NaN  ...
# 10959             NaN           5.0         17.7      2          NaN  ...
# 19208             3.0           2.0         80.0      2          NaN  ...
# 19430             2.6           5.0         16.5      1          NaN  ...
#
#        parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 1590                0.0         3064.0               1.0          264.0
# 10959               0.0         3190.0               1.0          431.0
# ...

# %% [markdown]
# Таким образом, заполнен столбец `parks_around3000` нулевыми значениями. Соответсвующие строки в столбце `parks_nearest` оставлены как есть. Пропуски в столбце с близлежащими парками означают, что парки отсутствуют в окрестности как минимум 3000м.

# %% [markdown]
# 8. Пропущенные значения в апартаментах `is_apartment` заполним на `False`, т.к. если квартира является апартаментами, то ячейка будет заполнена как `True`.<a id='aparts'></a>

# %%
# В апартаментах заменим Nan на false
df['is_apartment'] = df['is_apartment'].fillna(False)

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> False тут выглядит оптимальным вариантом для заполнения

# %% [markdown]
# 9. Исследуем пропуски в столбце с высотой потолков `ceiling_height`. Количество пропусков равно 38,8%

# %%
df['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# В данных есть аномальные величины: высота потолка не может быть 1м и 100м. При этом средние и медианные значения 2,8м и 2,6м соответсвенно выглядят правдоподобно.
# Исследуем строки с аномально большими значениями высоты потолка. Аномальными будем считать потолки ниже двух метров и выше шести метров, предполагая, что есть, например, двухэтажные квартиры.

# %%
# Выделим строки с высотой более 6м
df.query('ceiling_height > 6')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 355              17   3600000.0        55.2           2018-07-12      2
# 3148             14   2900000.0        75.0           2018-11-12      3
# 3474              3   1400000.0        30.0           2018-03-16      1
# 4643              0   4300000.0        45.0           2018-02-01      2
# 4876              7   3000000.0        25.0           2017-09-27      0
# 5076              0   3850000.0        30.5           2018-10-03      1
# 5246              0   2500000.0        54.0           2017-10-13      2
# 5669              4   4400000.0        50.0           2017-08-08      2
# 5807             17   8150000.0        80.0           2019-01-09      2
# 5863             20   5650000.0        45.0           2018-08-15      1
# 6246              6   3300000.0        44.4           2019-03-25      2
# 9379              5   3950000.0        42.0           2017-03-26      3
# ...

# %%
# Выделим строки с высотой ниже 2м
df.query('ceiling_height < 2.0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5712              5   1500000.0        42.8           2017-08-14      2
# 16934             5   4100000.0        40.0           2017-10-17      1
# 22590            16   6000000.0        55.0           2018-10-31      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 5712             1.20           2.0         27.5      1         False  ...
# 16934            1.75          37.0         17.4      5         False  ...
# 22590            1.00          12.0         32.4      7         False  ...
#
#        parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 5712                0.0            NaN               0.0            NaN
# 16934               0.0            NaN               3.0           80.0
# 22590               2.0          293.0               2.0          289.0
#
#       days_exposition        city_name  area_group  area_ratio  kitchen_ratio  \
# ...

# %% [markdown]
# Исправим данные в столбце `ceiling_heiqht`:
# 1. Значения больше 20 и меньше 40 разделим на 10, т.к. вероятно, что ошиблись знаком при внесении данных.
# 2. Значения больше 6 и меньше 19, а также 100, ошибочные. Заменим их на NaN.
# 3. Значения меньше двух тоже принимаем как ошибочные. Заменим их на NaN.
# 4. Заменим NaN на медианные значения.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Здорово, что сразу обработал аномалии

# %%
# Заменим пропуски в ceiling_heiqht в диапазоне между 20 и 40
df['ceiling_height'] = df['ceiling_height'].where(
    (df['ceiling_height'] < 20) | (df['ceiling_height'] > 40), df['ceiling_height'] / 10
)

# Заменим пропуски в ceiling_heiqht в диапазоне между 6 и 19
df['ceiling_height'] = df['ceiling_height'].where(
    (df['ceiling_height'] < 6) | (df['ceiling_height'] > 19), np.nan
)

# Заменим пропуски в ceiling_heiqht < 2
df['ceiling_height'] = df['ceiling_height'].where(
    (df['ceiling_height'] >= 2), np.nan
)

# Заменим в ceiling_heiqht значение 100 на NaN
df['ceiling_height'] = df['ceiling_height'].replace(100, np.nan)

# Заменим оставшиеся пропуски на медианные значения
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())

# %%
# Посторим гистограмму с данными по высотам потолков.
df['ceiling_height'].hist(bins=50);

# %% [markdown]
# На гистрограмме с высотами потолков видно нормальное распределение без аномальных выбросов.
# Пропуски могли возникнуть из-за того, что пользователи не вносили данные в объявление. Аномальные величины связаны с возможными опечатками при заполнении данных.
# Аномальные значения были откорректированы. Пропуски заполнены медианными значениями.

# %% [markdown]
# 10. Пропуски в столбце с балконами `balcony`. Количество пропусков 48,6%.

# %%
# Исследуем параметры столбца с данными о балконах
df['balcony'].describe()
# Out:
# count    12180.000000
# mean         1.150082
# std          1.071300
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          5.000000
# Name: balcony, dtype: float64

# %% [markdown]
# Подозрительно выглядит количество балконов равное пяти.

# %%
df.query('balcony > 4')['balcony'].count()
# Out:
# 304

# %% [markdown]
# Однако всего 304 объявления с пятью балконами, значит не считаем это аномальным выбросом.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Нуль тут хорошая альтернатива пропускам

# %%
# Заполним пропуски в столбце с балконами нулевыми знаачениями.
df['balcony'] = df['balcony'].fillna(value=0)

# %% [markdown]
# Пропущенные значения соответствют отсутствию балконов в квартире, поэтому пропуски были заменены нулями.

# %% [markdown]
# ### Исправление типов данных

# %% [markdown]
# Исправить типы данных необходимо в столбцах: `floors_total`, `parks_around3000`, `ponds_around3000`, `days_exposition`.
#
# `first_day_exposition` - тип данных был исправлен на `datetime` [ранее](#date).
#
# `is_apartment` - при заполнении пропусков тип стал `bool` ([см. выше](#aparts)).

# %%
# Исправляем float на int 
df['floors_total'] = df['floors_total'].astype('int')
df['parks_around3000'] = df['parks_around3000'].astype('int')
df['ponds_around3000'] = df['ponds_around3000'].astype('int')
df['days_exposition'] = df['days_exposition'].astype('int')

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Такие данные смотрятся здесь лучше

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  int64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  float64
# ...

# %% [markdown]
# ### Выводы

# %% [markdown]
# В данном разделе были проанализированы столбцы на пропуски и аномалии.
# Были заполнены пропуски в столбцах:
# - `floors_total`
# - `living_area`
# - `kitchen_area`
# - `days_exposition`
# - `ponds_around3000`
# - `parks_around3000`
# - `is_apartment`
# - `ceiling_height`
# - `balcony`
#
# Столбцы были оставлены без изменения, т.к. невозможно или затруднительно установить связь с другими параметрами:
# - `locality_name`
# - `ponds_nearest`
# - `parks_nearest`
# - `airports_nearest`
# - `cityCenters_nearest`
#
# Среди причин пропущенных данных можно выделить следующие:
# - данные не указаны пользователем или ошибка выгрузки: `locality_name`, `floors_total`.
# - данные не указаны пользователем: `living_area`, `kitchen_area`, `ceiling_height`.
# - пропуск, так как объект отстутствует: `ponds_around3000`, `parks_around3000`, `ponds_nearest`, `parks_nearest`, `is_apartment`, `balcony`.
#
# В столбцах `floors_total`, `parks_around3000`, `ponds_around3000`, `days_exposition` был заменен тип данных на целочисленный.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Отличный раздел работы, все операции над данными проведены абсолютно верно!

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Расчет цены квадратного метра

# %%
# Цена квадратного метра
df['sqm_costs'] = df['last_price'] / df['total_area']

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %%
# День недели публикации объявления
df['day_exposition'] = df['first_day_exposition'].dt.day_name()

# Месяц подачи объявления
df['month_exposition'] = df['first_day_exposition'].dt.month_name()

# Год подачи объявления
df['year_exposition'] = df['first_day_exposition'].dt.year

# %% [markdown]
# ### Этаж квартиры: первый, последний, другой.

# %%
# Функция определяющая этаж: первый, последний, другой.
def floor_type(row):
    if row['floor'] == 1:
        return 'первый'
    if row['floor'] - row['floors_total'] == 0:
        return 'последний'
    return 'другой'

df['floor_type'] = df.apply(floor_type, axis=1)

# %% [markdown]
# ### Cоотношение жилой и общей площади, а также отношение площади кухни к общей.

# %%
# соотношение жилой и общей площади
df['area_ratio'] = df['living_area'] / df['total_area']

# отношение площади кухни к общей
df['kitchen_ratio'] = df['kitchen_area'] / df['total_area']

# %% [markdown]
# ### Выводы
# В данном разделе были проведены расчеты:
# 1. Вычислена цена квадратного метра и добавлен столбец `sqm_costs`.
# 2. Добавлены в таблицу день недели `day_exposition`, месяц `month_exposition` и год `year_exposition` публикации объявления.
# 3. Добавлена информация по этажам: первый, последний и другой и столбец `floor_type`.
# 4. Вычислено отношение жилой и общей площади `area_ratio`, отношение площади кухни и общей площади `kitchen_ratio`.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Великолепно, все пункты задания выполнены в полном объёме

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра

# %% [markdown]
# 1. Исследование общей площади:

# %%
df['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
df['total_area'].hist(bins=50, figsize=(12,6))
plt.show()
df['total_area'].hist(bins=50, figsize=(12,6), range=(0,250));

# %% [markdown]
# По гистограмме распределение нормальное.
# Минимальная площадь 12 кв.м. Максимальная площадь 900 кв.м.
# Среднее 60 кв.м. Медианное 52 кв.м.
# С данными все в порядке.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Молодец, что сразу описываешь данные

# %% [markdown]
# 2. Исследование цены

# %%
df['last_price'].describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %%
df['last_price'].hist(bins=50, figsize=(12,6))
plt.show()
df['last_price'].hist(bins=50, figsize=(12,6), range=(0,4e7));

# %% [markdown]
# По гистограмме распределение нормальное.
# Минимальная цена 1,2е4 ед. Максимальная цена 7,6е8 ед.
# Среднее 6,5е6 ед. Медианное 4,6е6.
# С данными все в порядке.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Верно

# %% [markdown]
# 3. Исследование числа комнат.

# %%
df['rooms'].describe()
# Out:
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %%
df['rooms'].hist(bins=40, figsize=(12,6));

# %% [markdown]
# По гистограмме распределение нормальное.
# Минимальное количество комнат 0 - ошибочное значение.
# Максимальное количество комнат 19.
# Среднее и медианное равно 2.
# С данными все в порядке, кроме нулевых комнат.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Да, все так и есть

# %% [markdown]
# 4. Высота потолков

# %%
df['ceiling_height'].describe()
# Out:
# count    23699.000000
# mean         2.696721
# std          0.220087
# min          2.000000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          5.800000
# Name: ceiling_height, dtype: float64

# %%
df['ceiling_height'].hist(bins=30, figsize=(12,6));

# %% [markdown]
# По гистограмме распределение нормальное.
# Минимальная высота 2 м. Максимальная высота 5,8 м.
# Среднее и медианное 2,7 м.
# С данными все в порядке.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Соглашусь

# %% [markdown]
# ### Изучите время продажи квартиры

# %%
# Исследуем время продажи квартиры
df['days_exposition'].describe()
# Out:
# count    23699.000000
# mean       185.821722
# std        233.380877
# min          0.000000
# 25%         43.000000
# 50%         94.000000
# 75%        237.000000
# max       1618.000000
# Name: days_exposition, dtype: float64

# %%
# Построим гистограммы
df['days_exposition'].hist(bins=50, figsize=(12,6))
plt.show()
df['days_exposition'].hist(bins=100, figsize=(12,6), range=(0,100));

# %% [markdown]
# Аномально короткие значения равны нулю. Таких значений немного. Нулевые значения соответствуют строкам, в которых дата публикации совпадает с датой выгрузки базы.
# На гистограмме наблюдаются выбросы в значениях 45, 60 и 90. Необходимо изучить причины этих выбросов.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Отличный анализ days_exposition

# %% [markdown]
# ### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %% [markdown]
# 1. Аномальные значения в `days_exposition`

# %% [markdown]
# В данном разделе исследуем причины выбросов в значениях 45, 60 и 90 в столбце `days_exposition`.
#
# Проверим как часто встречаются даные по количеству дней до продажи квартиры.

# %%
df['days_exposition'].value_counts().head(10)
# Out:
# 45    908
# 60    559
# 7     269
# 30    230
# 4     212
# 90    204
# 3     183
# 11    181
# 9     175
# 5     170
# Name: days_exposition, dtype: int64

# %% [markdown]
# Наиболее часто встречаются данные - 7, 30, 45, 60, 90. Эти значения совпадают с выбросами на гистограмме.
# Возможно, что эти значения соотвествуют платным объявлениям, которые были опубликованы на определенный срок. И после окончания срока объвления были сняты с публикации.
# Очистим базу от платных объявлений и объявлений с нулевой длительностью.

# %%
free_ads_df = df.query('days_exposition not in [0, 7, 30, 45, 60, 90]')

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> "Редкие и выбивающиеся" значения есть не только в days_exposition и убрать их можно не только оттуда, обрати пожалуйста на это внимание и дополни этот раздел

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#
# Добавил исследование ниже в этом разделе:
# * Аномальные значения жилой площади
# * Проверка значений, в которых сумма жилой площади и кухни больше общей площади
# * Аномальные цены квартир
# </div>

# %%
# Исследуем время продажи квартиры
free_ads_df['days_exposition'].describe()
# Out:
# count    21509.000000
# mean       200.020736
# std        240.382020
# min          1.000000
# 25%         43.000000
# 50%        112.000000
# 75%        263.000000
# max       1618.000000
# Name: days_exposition, dtype: float64

# %%
# Построим диаграмму размаха
plt.boxplot(free_ads_df['days_exposition'])
plt.grid(True)
plt.ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %%
# Построим гистограммы
free_ads_df['days_exposition'].hist(bins=50, figsize=(12,6), range=(0,500));

# %% [markdown]
# Среднее значение времени продажи квартиры равно 200 дней, медианное равно 112 дней.
# Межквартильный диапазон равен от 43 до 263 дней. Диаграмма размаха охватывает диапазон от 1 до 593 дней. Значит продажи более 593 дней являются аномально долгими.

# %% [markdown]
# 2. Аномальные значения жилой площади

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#
# Исследование аномальных значений жилой площади
# </div>

# %% [markdown]
# Проверим жилую площадь квартир.

# %%
df['living_area'].describe()
# Out:
# count    23699.000000
# mean        34.541634
# std         22.591085
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %%
df['living_area'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %% [markdown]
# В жилой площади присутствует минимальное значение равное 2 кв.м. Величина аномально маленькая. Проверим количество квартир с жилой площадью менее 10 м.

# %%
df[df['living_area'] < 10]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 114               5   4000000.0       21.40           2019-02-07      1
# 680              14   7200000.0       43.00           2017-10-31      1
# 1326              8   8100000.0       52.00           2017-01-29      2
# 2309             10   4200000.0       62.40           2017-06-15      2
# 3242              7   4440000.0       41.00           2017-07-02      1
# 4100             17   5300000.0       34.80           2017-06-19      1
# 4542             12   3300000.0       18.00           2018-11-07      1
# 7312              8   3400000.0       27.00           2018-02-21      2
# 8325              9   4800000.0       52.00           2017-10-25      2
# 13915            20   6350000.0       52.00           2018-02-06      2
# 15833            20   4600000.0       33.00           2017-01-01      1
# 16431            13   3799000.0       31.00           2018-04-12      1
# ...

# %% [markdown]
# Всего обнаружено 28 объявлений с площадью менее 10 кв.м. Таких значений немного, поэтому удалим из таблицы.

# %%
df = df[df['living_area'] >= 10]

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Все замечательно

# %% [markdown]
# 3. Проверка значений, в которых сумма жилой площади и кухни больше общей площади

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#
# Исследование значений, в которых сумма жилой площади и кухни больше общей площади
# </div>

# %%
df['delta'] = df['total_area'] - df['living_area'] - df['kitchen_area']

# %%
df['delta'].describe()
# Out:
# count    23671.000000
# mean        15.370846
# std         12.314335
# min        -29.800000
# 25%          9.500000
# 50%         13.000000
# 75%         17.700000
# max        378.300000
# Name: delta, dtype: float64

# %% [markdown]
# В данных обнаружены квартиры, для которых общая площадь меньше, чем сумма жилой площади и кухни.

# %%
df[df['delta'] <= 0]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 184               7   2600000.0       30.20           2018-02-14      1
# 220               8   3890000.0       37.00           2018-07-09      1
# 424              14  11500000.0       98.00           2016-05-10      3
# 440               8   2480000.0       27.11           2018-03-12      0
# 545               9   4700000.0       23.80           2018-12-28      1
# ...             ...         ...         ...                  ...    ...
# 22963            16   3150000.0      102.00           2018-06-26      5
# 23191             3   1900000.0       18.90           2016-04-04      1
# 23202            13   4919880.0       67.92           2018-10-23      2
# 23297            10   1850000.0       48.20           2019-03-13      2
# 23680            14   5000000.0       59.00           2019-04-04      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# ...

# %% [markdown]
# Всего обнаружено 197 записей. Это составляет менее одного процента данных, поэтому исключим данные из анализа, т.к. это не повлияет на общую статистику.

# %%
df = df[df['delta'] > 0]
df = df.drop('delta', axis=1).reset_index()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Да, молодец

# %% [markdown]
# 4. Аномальные цены квартир

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b>
#
# Исследование аномальных цен квартир
# </div>

# %%
df['last_price'].describe()
# Out:
# count    2.347400e+04
# mean     6.542557e+06
# std      1.087717e+07
# min      1.219000e+04
# 25%      3.440000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Минимальное значение равно 12190 р. - аномально низкое значение для стоимости квартиры. Проверим цены квартир менее 100000 р.

# %%
df[df['last_price'] <= 100000]
# Out:
#       index  total_images  last_price  total_area first_day_exposition  rooms  \
# 8712   8793             7     12190.0       109.0           2019-03-20      2
#
#       ceiling_height  floors_total  living_area  floor  ...        city_name  \
# 8712            2.75            25         32.0     25  ...  Санкт-Петербург
#
#       area_group  area_ratio  kitchen_ratio  delta_day   sqm_costs  \
# 8712         150    0.293578        0.37156    44 days  111.834862
#
#       day_exposition  month_exposition  year_exposition  floor_type
# 8712       Wednesday             March             2019   последний
#
# [1 rows x 33 columns]

# %% [markdown]
# Обнаружена одна строка со стоимостью квартиры менее 100000р. Исключим эту запись из данных, т.к. она не повлияет на общую статистику.

# %%
df = df[df['last_price'] > 100000]

# %%
df['last_price'].describe()
# Out:
# count    2.347300e+04
# mean     6.542835e+06
# std      1.087732e+07
# min      4.300000e+05
# 25%      3.440000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Диапазон цен равен от 430 000 р. до 763 000 000 р. Аномальных значений не обнаружено.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Согласен

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры?

# %% [markdown]
# 1. Исследуем, зависит ли цена от площади, числа комнат, удалённости от центра.

# %%
# Соберем датафрейм из площади, комнат, расстояния до центра и цены
area_rooms_dist_df = df[['total_area', 'rooms', 'cityCenters_nearest', 'last_price']]

# %%
# Определим корреляцию между элементами датафрейма
print(area_rooms_dist_df.corr())

# Построим матрицу рассеяния параметров 
pd.plotting.scatter_matrix(area_rooms_dist_df, figsize=(16, 9));
# Out:
#                      total_area     rooms  cityCenters_nearest  last_price
# total_area             1.000000  0.757924            -0.232631    0.654022
# rooms                  0.757924  1.000000            -0.186588    0.362079
# cityCenters_nearest   -0.232631 -0.186588             1.000000   -0.206587
# last_price             0.654022  0.362079            -0.206587    1.000000

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Здорово, что анализируешь как линейную, так и нелинейную зависимость

# %% [markdown]
# Цена зависит от площади квартиры. Коэффциент Пирсона равен 0,65. Чем выше площадь, тем выше стоимость.
# Цена не зависит от количества комнат. Коэффициент Пирсона равен 0,36.
# Чем ближе квартира к центру, тем выше разброс цен. На расстоянии более 10000 м цена квартиры слабо зависит от удаленности от центра. Коэффицент Пирсона равен -0,2.

# %% [markdown]
# 2. Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.

# %%
da = df.pivot_table(index='floor_type', values='last_price', aggfunc='median').sort_values(by='last_price')

# %%
da.plot(y='last_price');

# %% [markdown]
# Цена квартиры зависит от этажа. На первом и последнем этажах квартиры самые дешевые. На последнем квартиры дороже чем на первом.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Здесь результат довольно предсказуем

# %% [markdown]
# 3. Изучим зависимость цены от даты размещения: дня недели, месяца и года.

# %%
# Зависимость цены от дня недели
days = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
df.pivot_table(index='day_exposition', values='last_price', aggfunc='median').reindex(days).plot(grid=True);

# %% [markdown]
# Во вторник публикуют объявления с наибольшей ценой. К выходным цена снижается и в воскресенье достигает минимума.

# %%
# Зависимость цены от месяца
month = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df.pivot_table(index='month_exposition', values='last_price', aggfunc='median').reindex(month).plot(grid=True);

# %% [markdown]
# Наибольшая цена на квартиры устанавливается в апреле, наименьшая - в июне. Обычно летом покупательная активность снижается.

# %%
# Зависимость цены от года
df.pivot_table(index='year_exposition', values='last_price', aggfunc='median').plot(grid=True);

# %% [markdown]
# С 2014 года медианная цена квартир снижается. В 2017 году стоимость достигла минимума и затем начала повышаться.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> По анализу временных параметров все также замечательно

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах.

# %%
# Создадим сводную таблицу с названием населенного пункта, количетсвом объявлений и средней ценой за квадратный метр
mean_city_costs = df.pivot_table(index='city_name', values='sqm_costs', aggfunc=['count', 'mean'])

# Переименуем столбцы
mean_city_costs.columns = ['count', 'mean']

# Выведем 10 городов с ниабольшим числом объявлений
mean_city_costs.sort_values(by='count', ascending=False).head(10)
# Out:
#                  count           mean
# city_name
# Санкт-Петербург  15572  114588.543355
# Мурино             578   85832.286683
# Кудрово            464   95227.100893
# Шушары             438   78699.244631
# Всеволожск         389   68611.636344
# Пушкин             369  103125.819291
# Колпино            337   75480.547446
# Парголово          326   90135.075586
# Гатчина            303   68625.141404
# Выборг             234   58303.714946

# %% [markdown]
# Из выбранных десяти населенных пунктов с наибольшим числом объявлений наибольшую среднюю стоимость квадратного метра имеет Санкт-Петербург, а наименьшую - Выборг.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Ты правильно ответил на вопрос задания!

# %% [markdown]
# ### Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге. Ваша задача — выяснить, какая область входит в центр.

# %% [markdown]
# Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется, — это и будет центральная зона.
# *Из формулировки задания непонятно, какую цену необходимо рассчитать: за квадратный метр или за квартиру. В данном разделе проведен анализ для цены квартиры.*

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Вообще за квадратный метр, но на самом деле график будет выглядеть примерно так же

# %%
# Создадим базу квартир по Санкт-Петербургу
center_area_df = df.query('city_name == "Санкт-Петербург"').copy()

# Подсчитаем пропуски в столбце `cityCenters_nearest` в %
print(center_area_df['cityCenters_nearest'].isna().sum() / len(center_area_df) * 100)
# Out:
# 0.39172874389930645

# %% [markdown]
# Пропуски в столбце `cityCenters_nearest` составляют менее 1% данных. Удалим строки с пропусками, т.к. их мало и они не повлияют на выборку.

# %%
# Удалим пропуски
center_area_df = center_area_df.dropna(subset = ['cityCenters_nearest']).reset_index(drop=True)

# Конвертируем расстояние из метров в км
center_area_df['cityCenters_nearest'] = center_area_df['cityCenters_nearest'] / 1000

# Построим диаграмму рассеяния
center_area_df.plot(y='last_price', x='cityCenters_nearest', kind='scatter', figsize=(12,5), grid=True);

# %%
# Округлим и изменим тип переменной на `int` в столбце `cityCenters_nearest`
center_area_df['cityCenters_nearest'] = center_area_df['cityCenters_nearest'].astype('int')

# Построим график цены от расстояния до центра
center_area_df.groupby('cityCenters_nearest')['last_price'].agg('mean').plot(grid=True, figsize=(12,5));

# %% [markdown]
# Анализ диаграммы рассеяния и графика зависимости цены от расстояния до центра показывает, что центральная зона ограничена радиусом 8км. На графике видно изменение наклона кривой. На диаграмме рассеяния видно, что в центральной зоне большой разброс цены. На удалении от центра разброс уменьшается и цена меньше зависит от удаления от центра.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Действительно, видимо 8 км это и есть центр города

# %% [markdown]
# ### Выделите сегмент квартир в центре. Проанализируйте эту территорию

# %% [markdown]
# Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?

# %% [markdown]
# 1. Исследуем, зависит ли цена от площади, числа комнат, высоты потолков.

# %%
# Соберем датафрейм для центральной зоны
center_aparts_df = center_area_df.query('cityCenters_nearest < 8')[['total_area', 'last_price', 'rooms', 'ceiling_height']]

# Рассчитаем корреляцию
display(center_aparts_df.corr())

# Построим матрицу рассеяния
pd.plotting.scatter_matrix(center_aparts_df, figsize=(16, 9));
# Out:
#                 total_area  last_price     rooms  ceiling_height
# total_area        1.000000    0.636347  0.736570        0.269200
# last_price        0.636347    1.000000  0.330166        0.141188
# rooms             0.736570    0.330166  1.000000        0.239609
# ceiling_height    0.269200    0.141188  0.239609        1.000000

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> И снова здорово, что анализируешь как линейную, так и нелинейную зависимость

# %% [markdown]
# Цена зависит от площади квартиры. Чем больше площадь, тем выше цена. Коэффициент Пирсона 0,64.
# Количество комнат и высота потолков слабо влияет на цену. Коэффициент Пирсона 0,33 и 0,26 соответственно.

# %% [markdown]
# 2. Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом

# %%
da = (
    center_area_df.
    query('cityCenters_nearest < 8').
    pivot_table(index='floor_type', values='last_price', aggfunc='median').
    sort_values(by='last_price')
)

# %%
da.plot(y='last_price');

# %% [markdown]
# Цена квартиры зависит от этажа. На первом и последнем этажах квартиры самые дешевые. На последнем квартиры дороже чем на первом.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Тут все похоже

# %% [markdown]
# 3. Изучим зависимость цены от удаленности от центра.

# %%
# Построим график медианной цены от расстояния до центра
(
    center_area_df.
    query('cityCenters_nearest < 8').
    groupby('cityCenters_nearest')['last_price'].
    agg('median').
    plot(grid=True, figsize=(12,5))
);

# %%
(
    center_area_df.
    query('cityCenters_nearest < 8').
    plot
    (
        y='last_price',
        x='cityCenters_nearest',
        kind='scatter',
        figsize=(12,5),
        grid=True
    )
);

# %% [markdown]
# В центральной части города наблюдается большой разброс по ценам. При это по медианныным значениям можно заметить зависимость цены от удаленности от центра: чем дальше от центра, тем дешевле.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Отлично

# %% [markdown]
# 4. Изучим зависимость цены от даты размещения: дня недели, месяца и года.

# %%
# Зависимость цены от дня недели
days = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
(
    center_area_df.
    query('cityCenters_nearest < 8').
    pivot_table
    (
        index='day_exposition',
        values='last_price',
        aggfunc='median'
    ).
    reindex(days).
    plot(grid=True)
);

# %% [markdown]
# По субботам публикуют самые дешевые квартиры. По понедельникам наиболее дорогие.

# %%
# Зависимость цены от месяца
month = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
center_area_df.query('cityCenters_nearest < 8').pivot_table(index='month_exposition', values='last_price', aggfunc='median').reindex(month).plot(grid=True)
# Out:
# <AxesSubplot:xlabel='month_exposition'>

# %% [markdown]
# В декабре публикуют объявления с самыми дешевыми ценами. В январе самые дорогие.

# %%
# Зависимость цены от года
center_area_df.query('cityCenters_nearest < 8').pivot_table(index='year_exposition', values='last_price', aggfunc='median').plot(grid=True)
# Out:
# <AxesSubplot:xlabel='year_exposition'>

# %% [markdown]
# Цена упала с 2014 до 2015 почти в два раза. В течение 2015-2019 гг. изменялась незначительно.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> По временным параметрам все также абсолютно верно

# %% [markdown]
# ### Выводы

# %% [markdown]
# В данном разделе были изучены следующие параметры: площадь, цена, число комнат, высота потолков и построены гистограммы для каждого параметра. Аномальных значений не обнаружено.
#
# Изучено время продажи квартиры. Построены гистограммы. Посчитаны среднее и медиана. Определены аномально короткие значения равные нулю и выбросы в значениях 45, 60 и 90. Среднее значение времени продажи квартиры равно 200 дней, медианное равно 112 дней. Межквартильнй диапазон равен от 43 до 263 дней. Диаграмма размаха охватывает диапазон от 1 до 593 дней. Значит продажи более 593 дней являются аномально долгими.
# Были удалены из базы аномально низкие значения в данных жилой площади и стоимости квартир.
#
# Изучены факторы, которые больше всего влияют на стоимость квартиры.
# Цена зависит от площади квартиры. Чем выше площадь, тем выше стоимость.
# Цена не зависит от количества комнат.
# Чем ближе квартира к центру, тем выше разброс цен. На расстоянии более 10000 м цена квартиры слабо зависит от удаленности от центра.
# Цена квартиры зависит от этажа. На первом и последнем этажах квартиры дешевле.
# Во вторник публикуют объявления с наибольшей ценой. К выходным цена снижается и в воскресенье достигает минимума.
# Наибольшая цена на квартиры устанавливается в апреле, наименьшая - в июне. Обычно летом покупательная активность снижается.
# С 2014 года медианная цена квартир снижается. В 2017 году стоимость достигла минимума и затем начала повышаться.
#
# Были выбранны десять населенных пунктов с наибольшим числом объявлений и была посчитана средняя стоимость квадранго метра. Наибольшую среднюю стоимость квадратного метра имеет Санкт-Петербург, а наименьшую - Выборг.
#
# Изучены предложения квартир и информация о расстоянии до центра. Анализ диаграммы рассеяния и графика зависимости цены от расстояния до центра показывает, что центральная зона ограничена радиусом 8км. На диаграмме рассеяния видно, что в центральной зоне большой разброс цены. На удалении от центра разброс уменьшается и цена меньше зависит от удаления от центра.
#
# Изучен сегмент квартир в центре и проанализирована эта территория.
# Цена зависит от площади квартиры. Чем больше площадь, тем выше цена. Количество комнат и высота потолков слабо влияет на цену.
# Цена квартиры зависит от этажа. На первом и последнем этажах квартиры дешевле.
# В центральной части города наблюдается большой разброс по ценам. При это по медианныным значениям можно заметить зависимость цены от удаленности от центра: чем дальше от центра, тем дешевле.
# По субботам публикуют самые дешевые квартиры. По понедельникам наиболее дорогие.
# В декабре публикуют объявления с самыми дешевыми ценами. В январе самые дорогие.
# Цена упала с 2014 до 2015 почти в два раза. В течение 2015-2019 гг. изменялась незначительно.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Ого, очень тщательное сравнение баз, все последовательно и понятно

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В отчете был проанализирован архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Были обнаружены и обработаны пропущенные значения и заполнены пропуски. Данные были привежены к нужному типу.
# Посчитали и добавили в таблицу цену квадратного метра, день недели, месяц и год публикации объявления, категории по этажам квартиры, соотношение жилой и общей площади, а также отношение площади кухни к общей.
# Провели исследовательский анализ данных. Изучили следующие параметры: площадь, цена, число комнат, высота потолков и построили гистограммы для каждого параметра. Аномальных значений не обнаружено.
#
# Изучили время продажи квартиры. Построили гистограммы. Посчитали среднюю и медиану. Определили аномально короткие значения равные нулю и выбросы в значениях 45, 60 и 90. Среднее значение времени продажи квартиры равно 200 дней, медианное равно 112 дней. Межквартильнй диапазон равен от 43 до 263 дней. Диаграмма размаха охватывает диапазон от 1 до 593 дней. Значит продажи более 593 дней являются аномально долгими.
#
# Изучили факторы, которые больше всего влияют на стоимость квартиры.
# Цена зависит от площади квартиры. Чем выше площадь, тем выше стоимость.
# Цена не зависит от количества комнат.
# Чем ближе квартира к центру, тем выше разброс цен. На расстоянии более 10000 м цена квартиры слабо зависит от удаленности от центра.
# Цена квартиры зависит от этажа. На первом и последнем этажах квартиры дешевле.
# Во вторник публикуют объявления с наибольшей ценой. К выходным цена снижается и в воскресенье достигает минимума.
# Наибольшая цена на квартиры устанавливается в апреле, наименьшая - в июне. Обычно летом покупательная активность снижается.
# С 2014 года медианная цена квартир снижается. В 2017 году стоимость достигла минимума и затем начала повышаться.
#
# Были выбранны десять населенных пунктов с наибольшим числом объявлений и была посчитана средняя стоимость квадранго метра. Наибольшую среднюю стоимость квадратного метра имеет Санкт-Петербург, а наименьшую - Выборг.
#
# Изучили предложения квартир и информацию о расстоянии до центра. Анализ диаграммы рассеяния и графика зависимости цены от расстояния до центра показывает, что центральная зона ограничена радиусом 8км. На диаграмме рассеяния видно, что в центральной зоне большой разброс цены. На удалении от центра разброс уменьшается и цена меньше зависит от удаления от центра.
#
# Изучен сегмент квартир в центре и проанализирована эта территория.
# Цена зависит от площади квартиры. Чем больше площадь, тем выше цена. Количество комнат и высота потолков слабо влияет на цену.
# Цена квартиры зависит от этажа. На первом этаже квартиры дешевле. На последнем этаже цена выше.
# В центральной части города наблюдается большой разброс по ценам. При это по медианныным значениям можно заметить зависимость цены от удаленности от центра: чем дальше от центра, тем дешевле.
# По субботам публикуют самые дешевые квартиры. По понедельникам наиболее дорогие.
# В декабре публикуют объявления с самыми дешевыми ценами. В январе самые дорогие.
# Цена упала с 2014 до 2015 почти в два раза. В течение 2015-2019 гг. изменялась незначительно.
#
# Сравнивая данные по всей базе и объявлениям, выделенным в центральной зоне, можно сделать следующие выводы:
# Цена квартиры зависит от её площади. Чем выше площадь, тем выше стоимость.
# Количество комнат и высота потолков не влияет на цену.
# Цена квартиры зависит от этажа. На первом и последнем этажах квартиры дешевле.
# Чем ближе квартира к центру, тем выше разброс цен. Чем дальше квартира от центра, тем дешевле. На расстоянии более 10000 м цена квартиры слабо зависит от удаленности от центра.
# По данным всей базы во вторник публикуют самые дешевые квартиры, а в воскресенье - дорогие. Для центральной зоны Санкт-Петербурга в субботу - самые дешевые, в понедельник - дорогие.
# Также наблюдаются различия по месяцам публикации. Для всей базы самые дорогие - в апреле, дешевые - в июне. Для Санкт-Петербурга: дешевые - в декабре, дорогие - в январе.
# Цена квартир по рынку росла с 2017 года. При этом в Санкт-Петербурге в период с 2015-2019 гг. стоимость менялась незначительно.
#
# Таким образом, есть параметры, которые едины для всего рынка, не зависят от локального сегмента, но влияют на стоимость, такие как площадь, этажность и удаление от центра. И есть параметры которые необходимо учитывать в зависимости от региона: день и месяц публикации и особенности регионального изменения стоимости квартиры.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Супер, подробные и хорошие выводы

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Евгений, проект отличный! У тебя очень сильные аналитические навыки и владение инструментами для проведения исследования. Но всё же в проекте есть несколько замечаний и я попрошу тебя исправить их, чтобы он стал еще лучше! </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: «Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?»
# - [x]  выполнено задание: «Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили».
# - [x]  выполнено задание: «Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года».
# - [x]  выполнено задание: «Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце `locality_name`».
# - [x]  выполнено задание: «Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (`locality_name`). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона».
# - [x]  выполнено задание: «Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всей базе?»
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
